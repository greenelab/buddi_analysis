# %% [markdown]
# # **Predict celltype-specific sex differences in mouse liver**
# In this notebook I use the models trained in the hyperparameter search in order to compare the performance of BuDDI in identifying which genes have the largest celltype-specific sex differences in the mouse liver.
#
# Here I compare against looking at sex-differences using bulk data only. We would expect that the bulk data would capture the differential genes of the most common cell-types, but perform not as well in the less frequent cell types.
#
# We will focus on the results from the PR curve and want to identify the top genes at the top of our DE results lists. Ideally, since bulk is a mix of cell types, BuDDI should be more specific for each cell-type. Bulk will identify the genes, but likely lower on the list.

# %% [markdown]
# # **Imports**

# %%
# import the VAE code
import sys
sys.path.insert(1, '../../')
sys.path.insert(1, '../')
from buddi import buddi
from buddi.preprocessing import sc_preprocess
from buddi.plotting import validation_plotting as vp


# general imports

import warnings
import numpy as np
import scanpy as sc
from scipy.stats import rankdata
from sklearn.metrics import average_precision_score, f1_score


# Images, plots, display, and visualization
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import scale, MinMaxScaler
from matplotlib_venn import venn2
from upsetplot import from_contents, UpSet

# programming stuff
import time
import os
import pickle
from pathlib import Path

# tensorflow stuff
import tensorflow as tf
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.utils import to_categorical, normalize, plot_model


# disable eager execution
# https://github.com/tensorflow/tensorflow/issues/47311#issuecomment-786116401
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
## parameters
sc_aug_data_path = f"{os.getcwd()}/../data/single_cell_data/augmented_liver_data/"
bulk_aug_data_path = f"{os.getcwd()}/../data/bulk_data/liver_sex/"
reference_data_path = f"{os.getcwd()}/../data/reference_data/"
res_data_path = f"{os.getcwd()}/../results/single_cell_data/buddiM2_liver/"

de_genes_path = f"{os.getcwd()}/../data/single_cell_data/liver_sex/de_pseudobulk_results.pkl"
de_bulk_path = f"{os.getcwd()}/../data/bulk_data/liver_sex/de_real_bulk_results.pkl"


cibersort_path = f"{os.getcwd()}/../data/single_cell_data/cibersort_liver/"


cibersort_genes_path = (f"{os.getcwd()}/../results/single_cell_data/cibersort_liver/" +
                        "CIBERSORTx_Job20_all-liver_0_cybersort_sig_inferred_phenoclasses" +
                        ".CIBERSORTx_Job20_all-liver_0_cybersort_sig_inferred_refsample.bm.K999.txt")


num_genes = 7000

exp_id = "all-liver"

# %% [markdown]
# # Set-up experimental variables

# %%
##################################################
#####. set up experiment specific variables
##################################################

# number expected cell types
n_cell_types = 8

# number of patients/domains/samples expected
n_tot_samples = 51 # 3 "patients", old / young

# number of drugs (one-hot encoded)
n_drugs = 2

# number of types of sequencing (one-hot encoded)
n_bulk = 2

# experiment id
lab_file_name = exp_id

# %% [markdown]
# # **Load / Pre-process data**
# Import pre-processed pseudobulks

# %%
in_name = "liver_bulk_processed"


# read in the real bulk data
processed_sc_file = f"{bulk_aug_data_path}/{in_name}.h5ad"
adata = sc.read_h5ad(processed_sc_file)


# now get the sc ref training data

# read in male first

X_concat = None
Y_concat = None
meta_concat = None
curr_samp = '30-M-5'
print(curr_samp)
pseudobulks_df, prop_df, gene_df, sig_df, metadata_df = sc_preprocess.read_single_liver_pseudobulk_file(sc_aug_data_path, curr_samp, "CTRL", "Train", exp_id)
pseudobulks_df.columns = gene_df

if X_concat is None:
    X_concat, Y_concat, meta_concat = pseudobulks_df, prop_df, metadata_df
else:
    X_concat = pd.concat([X_concat, pseudobulks_df])
    Y_concat = pd.concat([Y_concat, prop_df])
    meta_concat = pd.concat([meta_concat, metadata_df])

# now read in female
curr_samp = '18-F-51'
print(curr_samp)
pseudobulks_df, prop_df, gene_df, sig_df, metadata_df = sc_preprocess.read_single_liver_pseudobulk_file(sc_aug_data_path, curr_samp, "STIM", "Test", exp_id)
pseudobulks_df.columns = gene_df

X_concat = pd.concat([X_concat, pseudobulks_df])
Y_concat = pd.concat([Y_concat, prop_df])
meta_concat = pd.concat([meta_concat, metadata_df])



# read in the bulk data
real_bulk_df = pd.DataFrame(adata.X, columns=adata.var_names, index=adata.obs.index)
real_bulk_meta_df = adata.obs

# select genes that are in both
intersect_genes = np.intersect1d(gene_df, real_bulk_df.columns)
X_concat = X_concat[intersect_genes]
real_bulk_df = real_bulk_df[intersect_genes]

# get the bulk metadata formatted
real_bulk_meta_df = real_bulk_meta_df[["sample_id", "stim"]]
real_bulk_meta_df["isTraining"] = "Train"
real_bulk_meta_df["cell_prop_type"] = "realistic"
real_bulk_meta_df["samp_type"] = "bulk"
real_bulk_meta_df['sample_id'] = real_bulk_meta_df['sample_id'].astype(str)


# put the reference singlecell and real bulk it all together
X_full = pd.concat([X_concat, real_bulk_df])
Y_full = pd.concat([Y_concat, Y_concat.iloc[range(15)]]) ## stop gap for now
meta_df = pd.concat([meta_concat, real_bulk_meta_df])


# format the bulk data
real_bulk_df = pd.DataFrame(adata.X, columns=adata.var_names, index=adata.obs.index)
real_bulk_meta_df = adata.obs

# select genes that are in both
intersect_genes = np.intersect1d(gene_df, real_bulk_df.columns)
X_concat = X_concat[intersect_genes]
real_bulk_df = real_bulk_df[intersect_genes]

# now we have a new gene_df
gene_df = pd.DataFrame(intersect_genes)
gene_df.columns = ["gene_ids"]
gene_df.set_index(gene_df["gene_ids"])
gene_df = gene_df.gene_ids

# get the bulk metadata formatted
real_bulk_meta_df = real_bulk_meta_df[["sample_id", "stim"]]
real_bulk_meta_df["isTraining"] = "Train"
real_bulk_meta_df["cell_prop_type"] = "realistic"
real_bulk_meta_df["samp_type"] = "bulk"
real_bulk_meta_df['sample_id'] = real_bulk_meta_df['sample_id'].astype(str)

# put the reference singlecell and real bulk it all together
X_full = pd.concat([X_concat, real_bulk_df])
Y_full = pd.concat([Y_concat, Y_concat.iloc[range(real_bulk_df.shape[0])]]) ## stop gap for now
meta_df = pd.concat([meta_concat, real_bulk_meta_df])
# Out:
# 30-M-5
# 18-F-51
# <ipython-input-24-56fb875bd3e4>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_bulk_meta_df["isTraining"] = "Train"
# <ipython-input-24-56fb875bd3e4>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_bulk_meta_df["cell_prop_type"] = "realistic"
# <ipython-input-24-56fb875bd3e4>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_bulk_meta_df["samp_type"] = "bulk"
# <ipython-input-24-56fb875bd3e4>:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_bulk_meta_df['sample_id'] = real_bulk_meta_df['sample_id'].astype(str)
# <ipython-input-24-56fb875bd3e4>:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_bulk_meta_df["isTraining"] = "Train"
# <ipython-input-24-56fb875bd3e4>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_bulk_meta_df["cell_prop_type"] = "realistic"
# <ipython-input-24-56fb875bd3e4>:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_bulk_meta_df["samp_type"] = "bulk"
# <ipython-input-24-56fb875bd3e4>:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_bulk_meta_df['sample_id'] = real_bulk_meta_df['sample_id'].astype(str)

# %% [markdown]
# ### format sample indicies and get variable genes

# %%
##################################################
#####. Design the experiment
##################################################


X_orig = np.copy(X_full)

# set up the metadata arrays and indices
samp_label = np.asarray(meta_df.sample_id)
index_label, numeric_label = np.unique(samp_label, return_inverse=True)
Label_full = numeric_label
label_full = to_categorical(numeric_label)

samp_drug = np.asarray(meta_df.stim)
index_drug, numeric_drug = np.unique(samp_drug, return_inverse=True)
Drug_full = numeric_drug
drug_full = to_categorical(numeric_drug)

samp_bulk = np.asarray(meta_df.samp_type)
index_bulk, numeric_bulk = np.unique(samp_bulk, return_inverse=True)
Bulk_full = numeric_bulk
bulk_full = to_categorical(numeric_bulk)


idx_train = np.where(meta_df.isTraining=="Train")[0] 
idx_test = np.where(meta_df.isTraining!="Train")[0] 
idx_bulk = np.where(meta_df.samp_type == "bulk")[0]
idx_sc = np.where(meta_df.samp_type != "bulk")[0]
idx_drug = np.where(meta_df.stim == "STIM")[0]
idx_random = np.where(meta_df.cell_prop_type == "random")[0]

Y_max = np.copy(Y_full)
Y_max = np.argmax(Y_max, axis=1)
Y_max = Y_full.columns[Y_max]
meta_df["Y_max"] = Y_max

# now seperate out the training and testing data
X_train_df = X_full.iloc[idx_train]
Y_train_df = Y_full.iloc[idx_train]


# try using the cibersort genes
cibersort_df = pd.read_csv(cibersort_genes_path, sep="\t" )
cibersort_genes = cibersort_df["NAME"].values.tolist()

# only keep cibersort genes that are in common genes
cibersort_genes = np.intersect1d(gene_df, cibersort_genes)



# convert to data matrices
X_train = X_train_df.to_numpy()
Y_train = Y_train_df.to_numpy()

## get the top variable genes
X_colmean = X_train.mean(axis=0)
X_colvar = X_train.var(axis=0)
X_CoV = np.array(np.divide(X_colvar, X_colmean+0.001))
idx_top = np.argpartition(X_CoV, -6680)[-6680:] # num_genes # 6679
gene_df = gene_df.iloc[idx_top]

union_genes = np.union1d(gene_df, cibersort_genes)
len(union_genes)
# Out:
# 7000

# %% [markdown]
# ### normalize

# %%
X_full = X_full.loc[:,union_genes]

## normalize within sample
clip_upper = np.quantile(X_full, 0.9)
X_full = np.clip(X_full, 0, clip_upper)
scaler = MinMaxScaler()
scaler.fit(X_full)

# now normalize with the scaler trained on the 
# training data
X_full = np.clip(X_full, 0, clip_upper)
X_full = scaler.transform(X_full)


# for unknown proportions; 
# this is bulks used in training
idx_bulk_train = np.intersect1d(idx_bulk, idx_train) 
X_unkp = X_full[idx_bulk_train,]
label_unkp = label_full[idx_bulk_train,]
drug_unkp = drug_full[idx_bulk_train,]
bulk_unkp = bulk_full[idx_bulk_train,]
y_unkp = Y_full.iloc[idx_bulk_train]
y_unkp = y_unkp.to_numpy()

# for known proportions
idx_sc_train = np.intersect1d(idx_sc, idx_train) 
X_kp = X_full[idx_sc_train,]
label_kp = label_full[idx_sc_train,]
drug_kp = drug_full[idx_sc_train,]
bulk_kp = bulk_full[idx_sc_train,]
y_kp = Y_full.iloc[idx_sc_train]
y_kp = y_kp.to_numpy()
meta_kp = meta_df.iloc[idx_sc_train]

# %% [markdown]
# ### plot data

# %%
## plot samples
plot_df = vp.get_tsne_for_plotting(X_full)

fig, axs = plt.subplots(2, 3, figsize=(30,15))

# this is a vector that represents the cell-type with 
# the highest proportion 
Y_temp = np.copy(Y_full)
Y_temp = np.argmax(Y_temp, axis=1) 
Y_temp = Y_full.columns[Y_temp]


vp.plot_tsne(plot_df, meta_df.sample_id.to_numpy(), axs[0,0], title=f"", legend_title="Sample ID")
vp.plot_tsne(plot_df, meta_df.stim.to_numpy(), axs[0,1], title=f"", legend_title="Perturbation")
vp.plot_tsne(plot_df, meta_df.isTraining.to_numpy(), axs[0,2], title=f"", legend_title="Test/Train")
vp.plot_tsne(plot_df, meta_df.cell_prop_type.to_numpy(), axs[1,0], title=f"", legend_title="Cell prop. type")
vp.plot_tsne(plot_df, meta_df.samp_type.to_numpy(), axs[1,1], title=f"", legend_title="sample type")
vp.plot_tsne(plot_df, Y_temp, axs[1,2], title=f"", legend_title="Cell Type")


fig.suptitle("All Data, normalized using training data", fontsize=14)

axs[0,0].legend([],[], frameon=False)

fig.show()
# Out:
# /beevol/home/davidson/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /beevol/home/davidson/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 3649 samples in 0.026s...
# [t-SNE] Computed neighbors for 3649 samples in 0.777s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3649
# [t-SNE] Computed conditional probabilities for sample 2000 / 3649
# [t-SNE] Computed conditional probabilities for sample 3000 / 3649
# [t-SNE] Computed conditional probabilities for sample 3649 / 3649
# [t-SNE] Mean sigma: 1.161060
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 68.145782
# [t-SNE] KL divergence after 500 iterations: 0.961612
# (3649, 2)
# (3649, 2)

# %%
## plot samples
idx_interest = np.where(np.logical_and(meta_df.samp_type == "bulk", meta_df.isTraining == "Train"))[0]

plot_df = vp.get_pca_for_plotting(X_full[idx_interest])

fig, axs = plt.subplots(2, 3, figsize=(30,15))

Y_temp = np.copy(Y_full.iloc[idx_interest])
Y_temp = np.argmax(Y_temp, axis=1) 
Y_temp = Y_full.columns[Y_temp]

vp.plot_pca(plot_df, meta_df.sample_id.to_numpy()[idx_interest], axs[0,0], title=f"", alpha=1, legend_title="Sample ID")
vp.plot_pca(plot_df, meta_df.stim.to_numpy()[idx_interest], axs[0,1], title=f"", alpha=1, legend_title="Perturbation")
vp.plot_pca(plot_df, meta_df.isTraining.to_numpy()[idx_interest], axs[0,2], title=f"", alpha=1, legend_title="Test/Train")
vp.plot_pca(plot_df, meta_df.cell_prop_type.to_numpy()[idx_interest], axs[1,0], title=f"", alpha=1, legend_title="Cell prop. type")
vp.plot_pca(plot_df, meta_df.samp_type.to_numpy()[idx_interest], axs[1,1], title=f"", alpha=1, legend_title="sample type")
vp.plot_pca(plot_df, Y_temp, axs[1,2], title=f"", alpha=1, legend_title="Cell Type")


fig.suptitle("All Data, normalized using training data", fontsize=14)

axs[0,0].legend([],[], frameon=False)

fig.show()
# Out:
# (49, 2)
# (49, 2)

# %%
## plot samples
idx_interest = np.where(np.logical_and(meta_df.samp_type == "bulk", meta_df.isTraining == "Train"))[0]

plot_df = vp.get_tsne_for_plotting(X_full[idx_interest])

fig, axs = plt.subplots(2, 3, figsize=(30,15))

Y_temp = np.copy(Y_full.iloc[idx_interest])
Y_temp = np.argmax(Y_temp, axis=1) 
Y_temp = Y_full.columns[Y_temp]

vp.plot_tsne(plot_df, meta_df.sample_id.to_numpy()[idx_interest], axs[0,0], alpha=1, title=f"", legend_title="Sample ID")
vp.plot_tsne(plot_df, meta_df.stim.to_numpy()[idx_interest], axs[0,1], alpha=1, title=f"", legend_title="Perturbation")
vp.plot_tsne(plot_df, meta_df.isTraining.to_numpy()[idx_interest], axs[0,2], alpha=1, title=f"", legend_title="Test/Train")
vp.plot_tsne(plot_df, meta_df.cell_prop_type.to_numpy()[idx_interest], axs[1,0], alpha=1, title=f"", legend_title="Cell prop. type")
vp.plot_tsne(plot_df, meta_df.samp_type.to_numpy()[idx_interest], axs[1,1], alpha=1, title=f"", legend_title="sample type")
vp.plot_tsne(plot_df, Y_temp, axs[1,2], title=f"", alpha=1, legend_title="Cell Type")


fig.suptitle("All Data, normalized using training data", fontsize=14)

axs[0,0].legend([],[], frameon=False)

fig.show()
# Out:
# /beevol/home/davidson/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /beevol/home/davidson/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 48 nearest neighbors...
# [t-SNE] Indexed 49 samples in 0.000s...
# [t-SNE] Computed neighbors for 49 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 49 / 49
# [t-SNE] Mean sigma: 8.985739
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 55.917191
# [t-SNE] KL divergence after 500 iterations: 0.563619
# (49, 2)
# (49, 2)

# %% [markdown]
# # **Read in Trained Models**

# %%
res1_enc_unlab = tf.keras.models.load_model(f"{res_data_path}/model1_{exp_id}_encoder_unlab")
res1_enc_lab = tf.keras.models.load_model(f"{res_data_path}/model1_{exp_id}_encoder_lab")
res1_dec = tf.keras.models.load_model(f"{res_data_path}/model1_{exp_id}_decoder")
res1_classifier = tf.keras.models.load_model(f"{res_data_path}/model1_{exp_id}_classifier")


res2_enc_unlab = tf.keras.models.load_model(f"{res_data_path}/model2_{exp_id}_encoder_unlab")
res2_enc_lab = tf.keras.models.load_model(f"{res_data_path}/model2_{exp_id}_encoder_lab")
res2_dec = tf.keras.models.load_model(f"{res_data_path}/model2_{exp_id}_decoder")
res2_classifier = tf.keras.models.load_model(f"{res_data_path}/model2_{exp_id}_classifier")


res3_enc_unlab = tf.keras.models.load_model(f"{res_data_path}/model3_{exp_id}_encoder_unlab")
res3_enc_lab = tf.keras.models.load_model(f"{res_data_path}/model3_{exp_id}_encoder_lab")
res3_dec = tf.keras.models.load_model(f"{res_data_path}/model3_{exp_id}_decoder")
res3_classifier = tf.keras.models.load_model(f"{res_data_path}/model3_{exp_id}_classifier")
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ## Do latent space projectsions

# %% [markdown]
# ### drug perturbation

# %%
res1_meta_df, res1_decoded_0_0, res1_decoded_0_1, res1_top_genes = buddi.calc_buddi_perturbation(meta_df, X_full, Y_full, scaler, 
                                                                            res1_enc_unlab, res1_dec, batch_size=500, 
                                                                            genes_ordered=union_genes, 
                                                                            top_lim=100, use_buddi4=True)


res2_meta_df, res2_decoded_0_0, res2_decoded_0_1, res2_top_genes = buddi.calc_buddi_perturbation(meta_df, X_full, Y_full, scaler, 
                                                                            res2_enc_unlab, res2_dec, batch_size=500, 
                                                                            genes_ordered=union_genes, 
                                                                            top_lim=100, use_buddi4=True)


res3_meta_df, res3_decoded_0_0, res3_decoded_0_1, res3_top_genes = buddi.calc_buddi_perturbation(meta_df, X_full, Y_full, scaler, 
                                                                            res3_enc_unlab, res3_dec, batch_size=500, 
                                                                            genes_ordered=union_genes, 
                                                                            top_lim=100, use_buddi4=True)
# Out:
# /beevol/home/davidson/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# /beevol/home/davidson/checkouts/sc_bulk_ood/liver_analysis/../buddi/buddi.py:696: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_meta_df.isTraining = "Test"
# /beevol/home/davidson/checkouts/sc_bulk_ood/liver_analysis/../buddi/buddi.py:697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_meta_df.cell_prop_type = "cell_type_specific"
# /beevol/home/davidson/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# /beevol/home/davidson/checkouts/sc_bulk_ood/liver_analysis/../buddi/buddi.py:696: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_meta_df.isTraining = "Test"
# /beevol/home/davidson/checkouts/sc_bulk_ood/liver_analysis/../buddi/buddi.py:697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_meta_df.cell_prop_type = "cell_type_specific"
# /beevol/home/davidson/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# /beevol/home/davidson/checkouts/sc_bulk_ood/liver_analysis/../buddi/buddi.py:696: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_meta_df.isTraining = "Test"
# /beevol/home/davidson/checkouts/sc_bulk_ood/liver_analysis/../buddi/buddi.py:697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_meta_df.cell_prop_type = "cell_type_specific"

# %%
# identify how cell-type specific the DE genes are
cell_diff = from_contents(res1_top_genes)
ax_dict = UpSet(cell_diff, subset_size='count', orientation='horizontal', min_subset_size=5).plot()

cell_diff = from_contents(res2_top_genes)
ax_dict = UpSet(cell_diff, subset_size='count', orientation='horizontal', min_subset_size=5).plot()

cell_diff = from_contents(res3_top_genes)
ax_dict = UpSet(cell_diff, subset_size='count', orientation='horizontal', min_subset_size=5).plot()

# %% [markdown]
# ### load the single-nucleus DE results from external publication
#
# "Interplay Between GH-regulated, Sex-biased Liver Transcriptome and Hepatic Zonation Revealed by Single-Nucleus RNA Sequencing"
# Christine N Goldfarb, Kritika Karri, Maxim Pyatkov, David J Waxman
# Endocrinology, Volume 163, Issue 7, July 2022, bqac059, https://doi.org/10.1210/endocr/bqac059

# %%
from gene_lists import load_genelists

union_genes_cap, Pub_DE, Pub_DE_immune, Pub_DE_hepatic, Pub_DE_kupffer, Pub_DE_hsc = load_genelists(union_genes)

# %% [markdown]
# ### load bulk DE results

# %%
de_bulk = pickle.load(open( de_bulk_path, "rb" ))
de_bulk.index = [x.upper() for x in de_bulk.index] 
de_bulk = de_bulk.iloc[np.where(de_bulk.padj < 1)[0]]
intersect_bulk = np.intersect1d(de_bulk.index.to_list(), union_genes_cap)

bulk_sig_df = pd.DataFrame(union_genes_cap, index=union_genes_cap)
bulk_sig_df["padj"] = 1
padj_val = de_bulk.padj[intersect_bulk]
bulk_sig_df.padj.loc[intersect_bulk] = padj_val

bulk_sig_df["log10padj"] = -1*np.log10(bulk_sig_df.padj)

bulk_sig_df["log2FC"] = 1
fc_val = de_bulk.log2FoldChange[intersect_bulk]
bulk_sig_df.log2FC.loc[intersect_bulk] = np.abs(fc_val)

bulk_sig_df
# Out:
# <ipython-input-14-1b0febddcbf6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bulk_sig_df.padj.loc[intersect_bulk] = padj_val
# <ipython-input-14-1b0febddcbf6>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bulk_sig_df.log2FC.loc[intersect_bulk] = np.abs(fc_val)
#                            0  padj  log10padj  log2FC
# 0610005C13RIK  0610005C13RIK   1.0       -0.0     1.0
# 0610009B22RIK  0610009B22RIK   1.0       -0.0     1.0
# 0610010F05RIK  0610010F05RIK   1.0       -0.0     1.0
# 0610012G03RIK  0610012G03RIK   1.0       -0.0     1.0
# 0610031O16RIK  0610031O16RIK   1.0       -0.0     1.0
# ...                      ...   ...        ...     ...
# ZXDB                    ZXDB   1.0       -0.0     1.0
# ZYG11B                ZYG11B   1.0       -0.0     1.0
# ZYX                      ZYX   1.0       -0.0     1.0
# ZZEF1                  ZZEF1   1.0       -0.0     1.0
# A                          A   1.0       -0.0     1.0
#
# [7000 rows x 4 columns]

# %% [markdown]
# ### load single-cell DE genes result

# %%
de_genes = pickle.load(open( de_genes_path, "rb" ))
de_genes
# Out:
# {'hepatocyte': ['Rbp4',
#   'Rpl37',
#   'Serpina1d',
#   'Apoc1',
#   'Serpina1b',
#   'Itih2',
#   'Hmgcs2',
#   'Rpl36',
#   'Mgst1',
#   'Gnmt',
#   'Rplp1',
#   'Rps15',
#   'Rpl38',
#   'Ttr',
#   'Etfa',
#   'Ebpl',
#   'Pah',
#   'Amacr',
#   'Ndufa3',
#   'Rps8',
#   'Cox4i1',
#   'Aldh2',
#   'Atf5',
#   'Rps25',
#   'Hamp',
#   'Fau',
#   'Serpina1a',
#   'Rps27a',
#   'Rps14',
#   'Acaa1b',
#   'Ldha',
#   'Mup3',
#   'Atp5e',
#   'Ftcd',
#   'Prdx1',
#   'Ndufa13',
#   'Rpl35',
#   'Rpl28',
#   'Tst',
#   'Atp5g3',
#   'Fah',
#   'Rpl8',
#   'Rpl13a',
#   'Rps3a',
#   'Slc25a3',
#   'Uqcrq',
#   'Fbp1',
#   'Rpl14',
#   'Ttc36',
#   'Atp5b',
#   'Hebp1',
#   'Rps12',
#   'Otc',
#   'Eef1a1',
#   'Rps24',
#   'Gchfr',
#   'Ccbl2',
#   'Ftl1',
#   'Atp5a1',
#   'Igfbp4',
#   'Rps18',
#   'Hspd1',
#   'Ndufv3',
#   'Ran',
#   'Gstt1',
#   'Rps4x',
#   'Dpyd',
#   'Etfb',
#   'Serpina1c',
#   'Sod1',
#   'Rpl13',
#   'Gstz1',
#   'Hsd11b1',
#   'Rpl23',
#   'Chchd2',
#   'Hgd',
#   'Ndufc2',
#   'Acad11',
#   'Ndufa6',
#   'Got2',
#   'Uqcr11',
#   'Rpl7a',
#   'Ctsh',
#   'Pgls',
#   'Spr',
#   'Tmem93',
#   'Dak',
#   'Rpl9',
#   'Khk',
#   'Hmgcs1',
#   'Vamp8',
#   'Rps19',
#   'Rpl39',
#   'Rab1',
#   'Aldob',
#   'Rnase4',
#   'Uba52',
#   'Ndufa1',
#   'Caprin1',
#   'Nadk',
#   'Ndufb5',
#   'Pemt',
#   'Cdo1',
#   'Spcs1',
#   'Rps10',
#   'Rpl27a',
#   'Acadm',
#   'Uqcrh',
#   'H3f3b',
#   'Pgk1',
#   'Slc10a1',
#   'Prelid1',
#   'Eif3f',
#   'Ndufa7',
#   'Atp5g1',
#   'Uqcr10',
#   'Sqstm1',
#   'Gcat',
#   'Rps23',
#   'Rbpms2',
#   'Srsf5',
#   'Etfdh',
#   'Fth1',
#   'Mup2',
#   'Bccip',
#   'Bhmt',
#   'Atp5d',
#   'Rpl35a',
#   'Pnpla8',
#   'Rpl18a',
#   'Ndufs6',
#   'Cnih',
#   'Rpl24',
#   'Rpl32',
#   'Ppp1cb',
#   'Sc5d',
#   'Krt18',
#   'Ptma',
#   'Pabpc1',
#   'Pcbp1',
#   'Lamp2',
#   'Serpinc1',
#   'Pfn1',
#   'Acbd5',
#   '1110020G09Rik',
#   'Haao',
#   'Dcaf11',
#   'Atox1',
#   'Cox7a2l',
#   'Cyp2c70',
#   'Rps3',
#   'Ndufb11',
#   'Pex7',
#   'Acat3',
#   'Dbi',
#   'Cbs',
#   'Rpl27',
#   'Cald1',
#   'Rplp2',
#   'Fabp1',
#   'Cltc',
#   'Ly6e',
#   'Sub1',
#   'Rpl6',
#   'Fam25c',
#   'Elovl5',
#   'Sord',
#   'Emg1',
#   'Krt8',
#   'Rps26',
#   'Pbld2',
#   'Hrsp12',
#   'Ctage5',
#   'Mrpl30',
#   'Cox6c',
#   'Habp4',
#   'Rps17',
#   'Kng1',
#   'Ugt2a3',
#   'Nr2f6',
#   'Gcsh',
#   'Surf4',
#   'Alad',
#   'Rps20',
#   'Nr1i3',
#   'Rpl10',
#   'Gcdh',
#   'Eif4a2',
#   'Timm13',
#   'Acads',
#   'Aamp',
#   'Gdi2',
#   'Sdhc',
#   'Ube2d3',
#   'Fbxo8',
#   'Gpd1',
#   'Btf3l4',
#   'Pfdn5',
#   'Aars',
#   '2900064A13Rik',
#   'Ppa1',
#   'Reep6',
#   'Bsg',
#   'Gjb1',
#   'Setd3',
#   'Uqcrc1',
#   'Rps16',
#   'Slc25a25',
#   'Rcl1',
#   'Vdac1',
#   'Anapc13',
#   'Sec61b',
#   'Slc25a1',
#   'Sepx1',
#   'Rpl5',
#   'Psmc1',
#   '1810006K21Rik',
#   'Pam16',
#   'BC031181',
#   'Phb2',
#   'Cxcl12',
#   'Glyctk',
#   'Atp5o',
#   'Ier3ip1',
#   'Mrpl12',
#   'Rps11',
#   'Psmd13',
#   'Psap',
#   'Dld',
#   'Akr1c6',
#   'Tmem167',
#   'Ube2l3',
#   'Hspe1',
#   '9430023L20Rik',
#   'Cltb',
#   'Gnai3',
#   'Drap1',
#   'Tfpi2',
#   'Inmt',
#   'Tmem86b',
#   'Rpl12',
#   'Gas5',
#   'Rpl11',
#   'BC024386',
#   'Rplp0',
#   'Gabarap',
#   'Prdx6',
#   'Cox7c',
#   'Sephs2',
#   'Spp2',
#   'Chchd10',
#   'Sars',
#   '0610012G03Rik',
#   'Ugp2',
#   'Sep15',
#   'Cyc1',
#   'Shmt1',
#   'Scp2',
#   'Gnas',
#   'Myl6',
#   'Csnk2b',
#   'H1f0',
#   '5730469M10Rik',
#   'Brp44l',
#   'Higd1a',
#   'Cox8a',
#   'Cct2',
#   'Cct5',
#   'Ebp',
#   'Riok3',
#   'Pgam1',
#   'Nudc',
#   'Zfand3',
#   'Mdh1',
#   'Taok3',
#   'Sec14l4',
#   'Atg5',
#   'Eif3h',
#   'Snrpf',
#   'Tomm20',
#   'Evi5',
#   'Tsg101',
#   'Tmem33',
#   'Copb1',
#   'Cyp2j5',
#   'Rnf4',
#   'Cyb5',
#   'Lsm6',
#   'Cyb5r3',
#   'Hadh',
#   'Cisd1',
#   'Litaf',
#   'Rpl36a',
#   'Lcat',
#   'Romo1',
#   'Cdc34',
#   'Gsta3',
#   'Mrpl28',
#   'Mtfr1',
#   'Slc25a15',
#   'Mrpl2',
#   'Rpl15',
#   'Tm7sf2',
#   'Yipf4',
#   'Rab1b',
#   'Rnf11',
#   'Rpl36al',
#   'Sgk2',
#   'Cebpg',
#   'Arpc2',
#   'Rpl18',
#   'Mmd',
#   'Pdia3',
#   'Ifnar2',
#   'Btg2',
#   'Gm561',
#   'Gpx4',
#   'Rpl22',
#   'H2-K1',
#   'Rpl29',
#   'Nfib',
#   'Eif2s2',
#   'Banf1',
#   'Aup1',
#   'Pecr',
#   'Timm44',
#   'Ddt',
#   'Gng5',
#   'Rbm17',
#   'Ifitm3',
#   '1190003J15Rik',
#   'Cox17',
#   'Rpl19',
#   'Cd164',
#   'Glo1',
#   'Hmgn1',
#   'Ccs',
#   'Thrsp',
#   'Tm4sf4',
#   'Mrps17',
#   'Rer1',
#   'Rpl21',
#   'Aldh1a1',
#   'Eif1',
#   'Abhd14b',
#   'Epb4.1',
#   'Anapc5',
#   'Rab2a',
#   'Apof',
#   'Grpel1',
#   'Homer2',
#   'Agmat',
#   'Ahsa1',
#   'Agtr1a',
#   'Ces1g',
#   'Vdac3',
#   'Mlf2',
#   'Scand1',
#   'Pdhb',
#   'Rbm7',
#   'Bola2',
#   'Dcun1d1',
#   'Gamt',
#   'Akr7a5',
#   'Ostc',
#   'Prosc',
#   'Rnf167',
#   'Mrpl34',
#   'Hspb8',
#   'Tmem147',
#   'Mrpl52',
#   '1810058I24Rik',
#   'Aldh4a1',
#   'Nit2',
#   'Slc35d2',
#   'Psmd14',
#   'Aspdh',
#   'Skp1a',
#   'Atp5l',
#   'Fahd1',
#   'Akr1c14',
#   'Rnf10',
#   'Ndufs2',
#   'Atad3a',
#   'Ctnna1',
#   'Shmt2',
#   '1300001I01Rik',
#   'Cpox',
#   '0610009D07Rik',
#   'Fam96a',
#   'Cyp2a12',
#   'Hnrnpm',
#   'Ppib',
#   'Mrps10',
#   'Mrpl43',
#   'Timm10',
#   'Acat1',
#   'Acaa1a',
#   'Ap2s1',
#   'Uqcrc2',
#   'Tomm22',
#   'Reep3',
#   'Pop5',
#   'Rab18',
#   'Rpl3',
#   'Nr1h4',
#   'Sec11c',
#   'Lrpprc',
#   'Sec62',
#   'Hmgcl',
#   'Eci2',
#   'Nbr1',
#   'Acad8',
#   'Pebp1',
#   'Dynlrb1',
#   'Slc25a5',
#   'Gstm1',
#   'Sardh',
#   'Rps9',
#   'Tomm7',
#   'Drg1',
#   'Zfp771',
#   'AI462493',
#   'Commd6',
#   'Gng12',
#   'Nr3c1',
#   'Psmd8',
#   'Cebpa',
#   'Uox',
#   'Becn1',
#   'Rps2',
#   'Vti1b',
#   'Akr1c13',
#   'Brd4',
#   'Snrnp70',
#   'Atp6v1e1',
#   'Ndufa4',
#   'Srp9',
#   'Hibadh',
#   'Ugdh',
#   'Zfp36l1',
#   'Dennd5b',
#   'Gltpd2',
#   'Atp5f1',
#   'Sfpq',
#   'Echs1',
#   'Pdcd10',
#   'Sf3b5',
#   'Srsf1',
#   'Nsmce4a',
#   'Atp6v1g1',
#   'U2af1',
#   'Cept1',
#   'Nr1h3',
#   'Tgds',
#   'Rbx1',
#   'Tprgl',
#   'Mrps18b',
#   'Ephx2',
#   'Ppia',
#   'Dnajb11',
#   'Atp6v1f',
#   'Gapdh',
#   'Slc30a9',
#   'Oxr1',
#   'S100a13',
#   'Phb',
#   'Shfm1',
#   'Atp5g2',
#   'Myeov2',
#   'Sh3glb1',
#   'Kpna2',
#   'Ndufb10',
#   'Decr1',
#   'Ehhadh',
#   'Gfer',
#   'Cox5b',
#   'Bnip3',
#   'Mrpl13',
#   'Cuta',
#   'H2afv',
#   'Srrm1',
#   'Pttg1ip',
#   'Chd4',
#   'Mmp19',
#   'Mrpl54',
#   'Sypl',
#   'Trmt112',
#   '2410015M20Rik',
#   'Acaa2',
#   'Apom',
#   'Cdc26',
#   'Tomm6',
#   'Srrm2',
#   'Hagh',
#   'Psmb1',
#   'Ech1',
#   'Fam18b',
#   'Them4',
#   'Cdc42',
#   'Atp5j2',
#   '0610007C21Rik',
#   'Fgl1',
#   'Ndufc1',
#   'Eif3a',
#   'Rpl7',
#   'Lamtor2',
#   'Ppp2r5a',
#   'Agpat3',
#   'Xpot',
#   'Bnip3l',
#   'Ccdc58',
#   'Ccdc90a',
#   'Echdc3',
#   'Mapk1ip1l',
#   'D17Wsu104e',
#   'Gars',
#   'Tm2d2',
#   'Rps15a',
#   'Ube2g2',
#   'Sec31a',
#   'Ube2v2',
#   'Sept9',
#   'Snhg6',
#   'Nhp2',
#   'Pzp',
#   'Hint2',
#   'Psma4',
#   'Mtch2',
#   'Fam108a',
#   'Hmbs',
#   'Ubxn4',
#   'Anp32a',
#   'Pnpla2',
#   'Lrrc58',
#   'Zmym5',
#   'Fads2',
#   'Clpp',
#   'Hmgb1',
#   'Rad23a',
#   'Cldn12',
#   'Pon2',
#   'Dnaja3',
#   'Galk1',
#   'Sdc4',
#   'Nudcd2',
#   'Psmd2',
#   'Sat1',
#   'Mapre3',
#   'Snap47',
#   'Fxc1',
#   'Clta',
#   'Pdlim5',
#   'Arhgap29',
#   'Prkar1a',
#   'Rtn3',
#   'Crp',
#   'Ndufa10',
#   'Rps6kb1',
#   'Osbpl9',
#   'Prpf19',
#   'Nfs1',
#   'Fmo5',
#   'Gnb2',
#   'Abcb7',
#   'Ndufs8',
#   'Capza2',
#   'Nme2',
#   'Pddc1',
#   'Yy1',
#   'Rps13',
#   'Ubap2l',
#   'Fam103a1',
#   'Comt',
#   'Idh3g',
#   'Grsf1',
#   'Calm1',
#   'Mdh2',
#   'Anapc16',
#   'Gm16517',
#   'Rps27l',
#   'Fermt2',
#   'Tm7sf3',
#   'Adk',
#   'Mrpl33',
#   'Prrc2c',
#   'Ppp1r3c',
#   'Onecut2',
#   'Pipox',
#   'Snrpd2',
#   'Trip12',
#   'Fdft1',
#   'Stoml2',
#   'H2-T23',
#   'Acsl5',
#   'Hint1',
#   'Fars2',
#   'Mrps24',
#   '1110003E01Rik',
#   'Pcbd1',
#   'Ndufa11',
#   'Slx1b',
#   'Abhd5',
#   'Nisch',
#   'Mbl2',
#   'Rxrb',
#   'Irak1',
#   '1500032L24Rik',
#   '2810428I15Rik',
#   'Atp5h',
#   'Mff',
#   'Pfdn2',
#   'Aldh1a7',
#   'Mrps7',
#   'Pabpc4',
#   'Acp1',
#   'Akt2',
#   'Slc25a23',
#   'Supt4h1',
#   'Nol7',
#   'Impa1',
#   'Urod',
#   'Ppp1r2',
#   'Cxxc5',
#   'Klhdc2',
#   'Abhd11',
#   'Dera',
#   'Rapgef4',
#   'Pxmp2',
#   'Akr1a1',
#   '1110054M08Rik',
#   'Nek6',
#   'Tbc1d15',
#   '1810046J19Rik',
#   'Naca',
#   'Thoc7',
#   'G6pc',
#   'Trpc4ap',
#   'Prr13',
#   'Cyp2d40',
#   'Kdelr1',
#   'Ddah1',
#   '2310036O22Rik',
#   'Gatad1',
#   'Pabpn1',
#   'Pcnp',
#   'Morf4l1',
#   'Psma6',
#   'Lman2',
#   'Eci1',
#   'Rab43',
#   'Kars',
#   'Bhlhe40',
#   'Hmg20b',
#   'Tspan31',
#   'Fbl',
#   'Nsdhl',
#   'Lrrfip2',
#   'Zfp706',
#   'Mrpl11',
#   'Dpy30',
#   'Ndufb8',
#   'Galt',
#   'Psmb4',
#   'Acox2',
#   'Dstn',
#   'Get4',
#   'Dohh',
#   'Xrn2',
#   'Rpl23a',
#   'Ywhag',
#   'Hnrnpk',
#   'Rrbp1',
#   'Ak2',
#   'Acsm3',
#   'Naprt1',
#   'Adipor1',
#   'Rps7',
#   'Csrp2',
#   'Zc3h14',
#   'Tmem30a',
#   'Atp5j',
#   'Nfic',
#   'G3bp1',
#   'Tceb2',
#   'Rogdi',
#   'Nfil3',
#   'Cps1',
#   'Tra2a',
#   'Ceacam1',
#   'Ammecr1l',
#   'Polr2l',
#   'Hbp1',
#   'Btf3',
#   'Fndc3a',
#   'Syf2',
#   'Rbm8a',
#   'Rdh16',
#   'Synj2bp',
#   'Nedd4',
#   'Nab1',
#   'Sh3bgrl',
#   'Gadd45gip1',
#   'Pi4k2a',
#   'Golim4',
#   'Rab5a',
#   'Tmem11',
#   'Naa15',
#   'Cldn3',
#   'Rps6',
#   'Sf3b1',
#   'Trappc4',
#   'Pdha1',
#   'Frg1',
#   'Gm5617',
#   'BC056474',
#   'Dus1l',
#   'Spcs3',
#   'Aph1a',
#   'Wbp2',
#   'Usmg5',
#   'Ralbp1',
#   'Ywhae',
#   'Atp5c1',
#   'Kdelr2',
#   'Bckdhb',
#   'Ccni',
#   'Eif4a3',
#   'Cox7a2',
#   '3230401D17Rik',
#   'Lman1',
#   'Psmc5',
#   'Park7',
#   'Acsf3',
#   'Tdo2',
#   '2310003F16Rik',
#   'Cnih4',
#   'Manf',
#   'Zfand6',
#   'Pcca',
#   'Rnpep',
#   'Apoa1bp',
#   '2810007J24Rik',
#   'Ctsb',
#   'Arfgap2',
#   'Nme1',
#   'Dpp3',
#   'Dhx32',
#   'Trnau1ap',
#   'Rpl31',
#   'Nudt9',
#   'Psmc6',
#   'Npepl1',
#   'Vps36',
#   'Srsf10',
#   'Psma5',
#   'Ube2b',
#   'Sdhaf1',
#   'Eif5a',
#   'Uqcrfs1',
#   'Mylk',
#   'Chchd1',
#   'S100a10',
#   'Slc25a22',
#   'Mrpl9',
#   'Nkiras1',
#   'Psma7',
#   'Ufm1',
#   'Pdcd6',
#   '1110065P20Rik',
#   'Slmap',
#   'Mta2',
#   'Ptp4a1',
#   'Puf60',
#   'Apon',
#   'Dbt',
#   'Abhd12',
#   'Sod2',
#   'Pex3',
#   'Bscl2',
#   'Ap2b1',
#   'Chchd5',
#   'Zfp281',
#   'Macrod1',
#   'Calr',
#   'Atg3',
#   'Tmem37',
#   'Arpc5',
#   'Rpl4',
#   'Mcfd2',
#   'Aatf',
#   'Ap1s1',
#   'Tspo',
#   'Cox6b1',
#   'Keap1',
#   'Ndufb3',
#   'Spg21',
#   'Mettl7b',
#   'Thrb',
#   'D4Wsu53e',
#   'Fkbp1a',
#   'Psmd11',
#   'Faf1',
#   'Cab39l',
#   'Srxn1',
#   'D8Ertd738e',
#   'Bnip1',
#   'Fam53a',
#   'Arpp19',
#   'Bcl2l1',
#   'Skap2',
#   'Ak4',
#   'Rnf139',
#   'Ap1g1',
#   'Tra2b',
#   '2010107E04Rik',
#   'Tspan4',
#   'Ip6k1',
#   'Grcc10',
#   'Taldo1',
#   'Pdap1',
#   'Cgnl1',
#   'Mtch1',
#   'Taf9',
#   '0910001L09Rik',
#   'Mrps21',
#   'Ctnnb1',
#   'Snrnp200',
#   'Ube2i',
#   'Snrpg',
#   'Adck4',
#   'Actr10',
#   'Pir',
#   'Akt1s1',
#   'Ccdc72',
#   'Parl',
#   'Nek9',
#   'Nfyb',
#   'Ssr1',
#   'Aass',
#   'Obfc2b',
#   'Pex6',
#   '2410001C21Rik',
#   'Hmgn2',
#   'Pin1',
#   'Plg',
#   'Proz',
#   'Uroc1',
#   'Fbxw2',
#   'Npm1',
#   'Ddx3x',
#   'Arl6ip5',
#   'Frmd4b',
#   'Cnot2',
#   'Mocs2',
#   'Tcea1',
#   'Shpk',
#   'Dnajc25',
#   'Ufc1',
#   'Gm6484',
#   'Rai14',
#   'Idi1',
#   'Ppp1r11',
#   'Rexo2',
#   'Maob',
#   'Lect2',
#   'Smurf2',
#   'Serpind1',
#   'Tax1bp1',
#   'Mtdh',
#   'Gmfb',
#   'Cd1d1',
#   'Tubb2a',
#   'Chchd3',
#   'Oxnad1',
#   'G630090E17Rik',
#   'Ppp1cc',
#   'Atp5sl',
#   'Fam176a',
#   'Ube2m',
#   'Gabpa',
#   'Ggh',
#   'Eif4g1',
#   'C330006A16Rik',
#   'Tbl1xr1',
#   'Crcp',
#   'Hlf',
#   'Tm9sf3',
#   '2310003C23Rik',
#   'Ssb',
#   'Tmed3',
#   'Aff4',
#   'Glrx3',
#   'H2afz',
#   'Herpud2',
#   'Zmat2',
#   'Eif3k',
#   'Phf3',
#   'Rlim',
#   'Lap3',
#   '2210016F16Rik',
#   'Mrpl1',
#   'Lmo4',
#   'Tsc22d3',
#   'Elovl2',
#   'Fis1',
#   'Ranbp3',
#   'Ythdc1',
#   'Slc6a13',
#   '2310010J17Rik',
#   'Sar1a',
#   'Cadm1',
#   'Dpp9',
#   'Exosc3',
#   'Fam173b',
#   'Apol7a',
#   'Zfyve21',
#   'Rhot1',
#   'Naa10',
#   'Higd2a',
#   '2700089E24Rik',
#   'Yme1l1',
#   'Rab28',
#   'Timd2',
#   'Tbca',
#   'Tmpo',
#   'Acly',
#   'Psma2',
#   'Vps28',
#   'Eny2',
#   'Psmd6',
#   'Ccar1',
#   '1500012F01Rik',
#   'Mrpl17',
#   'Cpsf3l',
#   'Ppp1r14b',
#   'Gmps',
#   'Pacsin3',
#   'Sec13',
#   'Myg1',
#   'Pgcp',
#   'Sept2',
#   'Kif1c',
#   'Pum2',
#   'F9',
#   'Timm23',
#   '1190005I06Rik',
#   'Uchl5',
#   'Mbd2',
#   'Ube2e1',
#   'Epb4.1l5',
#   'Anxa5',
#   'Cox7b',
#   'Pfdn1',
#   'Bri3',
#   'Eif2a',
#   'Vps26b',
#   'Hgs',
#   'Myl12a',
#   'Nop10',
#   'D930014E17Rik',
#   'Capns1',
#   'Atp2b1',
#   'Fabp2',
#   'C1d',
#   'Akirin2',
#   'Cno',
#   '2310004I24Rik',
#   'Coq10a',
#   'Calm3',
#   'Yipf6',
#   'Acbd6',
#   'Phf5a',
#   'Imp3',
#   'Mrps16',
#   'Bcas2',
#   'Cfb',
#   'Iws1',
#   'Timm17b',
#   'Edf1',
#   'Txnl1',
#   'Ift46',
#   'Tcf7l2',
#   '1190007I07Rik',
#   'Lin7a',
#   'Gda',
#   'Cnbp',
#   'Nipsnap1',
#   'Rpl17',
#   'Cfl1',
#   'Car3',
#   'Gabarapl1',
#   'Vps41',
#   'Cyp4f14',
#   'Ccdc97',
#   'Prrc2a',
#   'Zdhhc9',
#   'Ugt2b34',
#   'Rnpepl1',
#   'Fam54b',
#   ...],
#  'hepatic_sinusoid': ['B2m',
#   'Gpr182',
#   'Egfl7',
#   'Rpl23a',
#   'Bmp2',
#   'Rpl7',
#   'Stab1',
#   'Rps25',
#   'Rpl27a',
#   'Plxnc1',
#   'Clec4g',
#   'Rpl35a',
#   'Sepp1',
#   'Cmtm8',
#   'Rps23',
#   'Rps3a',
#   'Myct1',
#   'Lifr',
#   'Akr1a1',
#   'Rps8',
#   'Chchd2',
#   'Rps3',
#   'Rpl19',
#   'Ybx1',
#   'A730098P11Rik',
#   'Gpihbp1',
#   'App',
#   'Itm2b',
#   'Atp5g2',
#   'Ptprb',
#   'Cd47',
#   'Ndufa7',
#   'Ddx5',
#   'Uqcr11',
#   'Tmem204',
#   'Adam23',
#   'H2-D1',
#   'Gpr116',
#   'Rpl21',
#   'Rpl38',
#   'Eef1a1',
#   'Slc25a3',
#   'Rpl37a',
#   'Tmem2',
#   'Sod1',
#   'Nedd8',
#   'Cox5b',
#   'Atp5l',
#   'Cox7a2',
#   'Pfdn5',
#   'Rpl29',
#   'Rps27a',
#   'Rpl12',
#   'Chmp4b',
#   'Pcbp1',
#   'Atp5j2',
#   'Cox17',
#   'Rps4x',
#   'Edf1',
#   'Prdx1',
#   'Clta',
#   'Flt4',
#   'Rpl18',
#   'Arhgef15',
#   'Lgals3bp',
#   'Atp6v0e',
#   'Sec61g',
#   'Eef1g',
#   'Atp6v1f',
#   'Cycs',
#   'Tceb2',
#   'Serpinb6a',
#   'Rpl27',
#   'Rpl10',
#   'Ctsl',
#   'Rbm39',
#   'Ramp2',
#   'Rpsa',
#   'Nme2',
#   'Rpl39',
#   'Sgk1',
#   'Gnb2l1',
#   'Rps13',
#   'Rps29',
#   'Sumo2',
#   'Cd59a',
#   'Myeov2',
#   'Rps27',
#   'Nr3c1',
#   'Hspa8',
#   'Gpx4',
#   'Rpl37',
#   'Snrpb',
#   'Mfsd5',
#   'Rbm3',
#   'Atp6ap1',
#   'Rps28',
#   'Ddx17',
#   'Itgb1',
#   'Cd300lg',
#   'Psmb10',
#   'Rpl6',
#   'Rps15a',
#   'Uqcrh',
#   'Minos1',
#   'Marcksl1',
#   'Tln1',
#   'Clec14a',
#   'Rpl13a',
#   'Rpl9',
#   'Rpl8',
#   'Rnf130',
#   'Amotl1',
#   'Rpl17',
#   'Dnase1l3',
#   'Cnbp',
#   'Reep5',
#   'Cdc42ep2',
#   'Fam176b',
#   'Rps14',
#   'Elk3',
#   'Mbnl1',
#   'Slc3a2',
#   'Stab2',
#   'Atp5f1',
#   'Hnrnpu',
#   'Cox4i1',
#   'Rpl11',
#   'AW112010',
#   'Cdc42',
#   'Rnaset2b',
#   'Srsf5',
#   'Tbca',
#   'Scaf11',
#   'Rps16',
#   'Nfkbia',
#   'Psmb3',
#   '1500032L24Rik',
#   'Arglu1',
#   'Mrpl52',
#   'Rps2',
#   'Atp5c1',
#   'Naca',
#   'Pcbp2',
#   'Tnfrsf1a',
#   'Gatm',
#   'Atp5b',
#   'Tmed10',
#   'Bax',
#   'Jak1',
#   'Nop10',
#   'Stx12',
#   'Cxcl16',
#   'Rnasek',
#   'Brd2',
#   'Manf',
#   'Dlc1',
#   'Ly6a',
#   'Snrnp27',
#   'Sepw1',
#   'Stard8',
#   'Fau',
#   'Rpl36',
#   'Cox7c',
#   'Hnrnpc',
#   'Prrc2b',
#   'Nol7',
#   'Ndufb6',
#   'Atp5j',
#   'Rpl22l1',
#   'Ivns1abp',
#   'Tmbim6',
#   'Gnb1',
#   'Rpl24',
#   'Ube2d3',
#   'Cox6a1',
#   'Ubb',
#   'F2r',
#   'Scarf1',
#   'Zfp706',
#   'Malat1',
#   'Bsg',
#   'Alb',
#   'Rps15a-ps4',
#   'Mrfap1',
#   'Psma4',
#   'Cd55',
#   'Scp2',
#   'Eif1',
#   '0610012G03Rik',
#   'Rps6',
#   'Rpl35',
#   'Rps7',
#   'Eif4ebp1',
#   'Rpl15',
#   'Psmd8',
#   'Eif5a',
#   'Ckap4',
#   'Srp9',
#   'Arf5',
#   'Ptpn12',
#   'Arl6ip1',
#   'Fli1',
#   'Cox7a2l',
#   'Rpl41',
#   'Prickle1',
#   'Uba52',
#   'Selk',
#   'Gemin7',
#   'Dse',
#   'Fmnl2',
#   'Npm1',
#   'Gm6402',
#   'Foxo1',
#   'Wbp5',
#   'Lpar6',
#   'Ndufb10',
#   'Papola',
#   'Celf1',
#   'Wdr1',
#   'Dcaf8',
#   'Atp2b1',
#   'Copa',
#   'Rps11',
#   'Emilin1',
#   'Dpagt1',
#   'Higd2a',
#   'Ppp1r2',
#   'Fam125a',
#   'F11r',
#   'Cstb',
#   'Ndufb11',
#   'Lphn2',
#   'Ssr4',
#   'Fam174a',
#   'Pxk',
#   'H3f3b',
#   'Ywhah',
#   'Ywhaz',
#   'Rtn3',
#   'Dnajc3',
#   'Anp32a',
#   'Rhoa',
#   'H2afz',
#   'Stx7',
#   'Tnks2',
#   'Tacc1',
#   'Clptm1l',
#   'Pnrc1',
#   'Mcl1',
#   'Sdcbp',
#   'Mrpl17',
#   'Ndufb9',
#   'Rpl13',
#   '2310008H09Rik',
#   'Capns1',
#   'Ubxn1',
#   'Rac1',
#   'Mgll',
#   'Trim30a',
#   'Gltscr2',
#   'Pnpla8',
#   'Cab39',
#   'Sin3b',
#   'Naa20',
#   'Nhp2l1',
#   'Cpne3',
#   'Ppig',
#   'Rps9',
#   'Cd81',
#   'Ptp4a2',
#   'Uqcrfs1',
#   'Gnai2',
#   'D4Ertd22e',
#   'Rpl18a',
#   'Serpinh1',
#   'Mrpl14',
#   'Atp1a1',
#   'Lamp1',
#   'Pkm2',
#   'Lpp',
#   'Rod1',
#   'Ndufs8',
#   'Golga7',
#   'Nagk',
#   'Hint1',
#   'Cox8a',
#   'Rer1',
#   'Derl1',
#   'Ccdc12',
#   'Taok1',
#   'Id1',
#   '2610001J05Rik',
#   'Dek',
#   'Serf2',
#   'Blvrb',
#   'Tubb5',
#   'Rsad2',
#   'Ndufv3',
#   '9530068E07Rik',
#   'Tgfbr2',
#   'Fkbp2',
#   'Tmsb4x',
#   'Cfh',
#   'Pttg1',
#   'Synj1',
#   'Btf3',
#   'Gabarap',
#   'Bag1',
#   'Dnajc8',
#   'Sumo3',
#   'Crk',
#   '1810035L17Rik',
#   'Bik',
#   'Vps36',
#   'Msr1',
#   'Ap1s1',
#   'Dock1',
#   'Mrps5',
#   'Fbxl17',
#   'Rps19',
#   'Fkbp8',
#   'Gimap4',
#   'B4galt1',
#   'Tpst2',
#   'Elf1',
#   'Mrpl3',
#   'Myl12b',
#   'Eef2',
#   'Slfn5',
#   'Pcna',
#   'Abcg1',
#   'Ap2m1',
#   'Spcs1',
#   'Tmem47',
#   'Psen2',
#   'Rpl10a',
#   'Pbrm1',
#   'Kif5b',
#   'Rpl36al',
#   'Mpp1',
#   'BC017612',
#   'Rps18',
#   'Ube2s',
#   'Hnrnpul2',
#   'Pin4',
#   'D17Wsu92e',
#   'Hpgd',
#   'Gm14005',
#   'Hs3st3b1',
#   '2410015M20Rik',
#   'Mapre2',
#   'Ube2a',
#   'Fam114a2',
#   'Ndufb2',
#   'Snx24',
#   'Mtch2',
#   'Sypl',
#   'Lsm4',
#   'Map2k2',
#   'Calm3',
#   'Tmem66',
#   'Xiap',
#   'Sec11a',
#   'Wac',
#   'Polr1d',
#   'Mrps21',
#   'D14Abb1e',
#   'Srsf9',
#   'Sel1l',
#   'Mosc2',
#   'Cpne2',
#   'Bcas2',
#   'Klf9',
#   'S100a1',
#   'Pip5k1c',
#   'Zmat2',
#   'Ndufs2',
#   'Srp14',
#   'Lrp5',
#   'Atox1',
#   'Sept10',
#   'Cfdp1',
#   'Chchd7',
#   'Dtnbp1',
#   'Pdlim1',
#   'Znhit1',
#   'Pdcd5',
#   'Timm13',
#   'Ube2d2',
#   'Cmpk1',
#   'Dgkz',
#   'Tmcc2',
#   'Psma6',
#   'Lrrfip1',
#   'Gipc1',
#   'Atxn2l',
#   'Cnksr3',
#   'Myo7a',
#   'Fam108a',
#   'Gnb2',
#   'C330006A16Rik',
#   'Capzb',
#   'Cyth2',
#   'Mrps12',
#   'Rragc',
#   'Gapdh',
#   'Dusp6',
#   'Rcn1',
#   'N4bp2l1',
#   'Ogdh',
#   'Eif3k',
#   'Ralgapa2',
#   'Ppp2r5a',
#   'Psap',
#   'Arrb2',
#   'Tgm2',
#   'Eif3g',
#   'Neurl3',
#   'Tomm5',
#   'Tmem64',
#   'Cfl1',
#   'AW549877',
#   'Wbp4',
#   'Znfx1',
#   'Tiprl',
#   'Sec61a1',
#   'Asah1',
#   'Grn',
#   'Stk25',
#   'Tmed9',
#   'Trappc2l',
#   'Ociad1',
#   'Srsf6',
#   'Bub3',
#   'Rpl32',
#   'Cuedc2',
#   'Eif4a2',
#   'Smagp',
#   'Rn45s',
#   'Frmd4b',
#   'Raly',
#   'Rnf14',
#   'A130040M12Rik',
#   'Aimp1',
#   'Ggnbp2',
#   'Snx3',
#   'Zfp36',
#   'Fcgrt',
#   'Spag7',
#   'Tmem88',
#   'Rap2c',
#   'Dda1',
#   'Psmb7',
#   'Bgn',
#   'Hdac7',
#   'Rps5',
#   'Ndufa6',
#   'Itga1',
#   'Rnf13',
#   'Prpf18',
#   'Rbm25',
#   'Hfe',
#   '2410006H16Rik',
#   'Slc39a7',
#   'Actr2',
#   'Ndrg1',
#   'Ndufa3',
#   'Ankrd17',
#   'Klf7',
#   'Atg5',
#   'Rps26',
#   'Hsd17b12',
#   'Ets1',
#   'Sbno1',
#   'Ddx39b',
#   'Ppp1cc',
#   'Ncoa3',
#   'Ube2l3',
#   'Tecr',
#   'Atp6v1c1',
#   'Tprgl',
#   '9430020K01Rik',
#   'Mfhas1',
#   'Aldoa',
#   'BC013529',
#   'Pdrg1',
#   'Tcf12',
#   'Cct4',
#   'Hmg20b',
#   'Ctbp1',
#   'Ckb',
#   'Msrb3',
#   'Polr2j',
#   'Tmem93',
#   'Rpl3',
#   'Hmox2',
#   'Dgcr2',
#   'Ostf1',
#   'Erlec1',
#   'Ost4',
#   '2900064A13Rik',
#   'Trim47',
#   'Ufm1',
#   'Arid2',
#   'C1qtnf1',
#   '1110058L19Rik',
#   '1110003E01Rik',
#   'Ssna1',
#   'Atp5e',
#   'Dennd5a',
#   'Tmem205',
#   'Ensa',
#   'Copz1',
#   'Thoc2',
#   'Rnf44',
#   'Id2',
#   'C1qbp',
#   'Ccni',
#   'Nucb1',
#   'Syf2',
#   'Atp6v1a',
#   'Hecw2',
#   'Mat2b',
#   'Gpr108',
#   'Add3',
#   'Lipa',
#   'Psmd7',
#   'Hspg2',
#   'Il10rb',
#   'Commd8',
#   'Hmox1',
#   'Top1',
#   'BC002163',
#   'Trappc3',
#   'Actg1',
#   'Mpnd',
#   'Wdr61',
#   'Sar1b',
#   'Ostm1',
#   'Tmsb10',
#   'Ndufa13',
#   'Rpl4',
#   'Rab11a',
#   'Tm2d2',
#   'Ssbp1',
#   'Fam89b',
#   'Phb2',
#   'Gdi2',
#   'Eif1ax',
#   'Bin1',
#   'Aff1',
#   'Pxn',
#   'Cmtm3',
#   'Grap',
#   'Cyth1',
#   'Csnk2a1',
#   'Fam105b',
#   'Acbd5',
#   'D17Wsu104e',
#   '0910001L09Rik',
#   'Cnn3',
#   'Chmp5',
#   'Comt',
#   'Lrpprc',
#   'Fos',
#   'Gng5',
#   'Stat1',
#   'B230219D22Rik',
#   'Ctsb',
#   'Tmem55b',
#   'Frmd8',
#   'Wdr37',
#   'Bak1',
#   'Neat1',
#   'Fam173a',
#   'Hnrnph1',
#   'Surf4',
#   'Mtus1',
#   'Echs1',
#   'Zfp36l1',
#   'Rprd1b',
#   'Iah1',
#   'Btg2',
#   'Ano6',
#   'Tmem9b',
#   'Mup3',
#   'Ccnl1',
#   'Zc3h7b',
#   'Sephs2',
#   'Commd6',
#   'Tmem63a',
#   'Prpsap1',
#   'Dpy19l1',
#   'Ccdc80',
#   'Gmfg',
#   'Tax1bp3',
#   'AI462493',
#   'Nbr1',
#   'Fam168b',
#   'Ergic3',
#   '1810009A15Rik',
#   'Filip1l',
#   'Sfpq',
#   'Cdc26',
#   'Sec61b',
#   'AI314180',
#   'Hoxb5',
#   'Atg3',
#   'Beta-s',
#   'Dhx15',
#   'Chmp2b',
#   'Bcl7b',
#   'Arhgdia',
#   'Lgals8',
#   'Rnf114',
#   'Cd36',
#   'Snw1',
#   'H47',
#   'Higd1a',
#   'Phactr2',
#   'Lrrc32',
#   'Ykt6',
#   'H3f3a',
#   'Alyref',
#   'Ccdc34',
#   'Ankrd12',
#   'Cbfa2t3',
#   'Rere',
#   'Magoh',
#   '2810025M15Rik',
#   'Rnase4',
#   'Bcl10',
#   'Mylip',
#   'Lsm14a',
#   'Tm4sf1',
#   'Wnk1',
#   'Pard3b',
#   'Ugp2',
#   'Fam49a',
#   'Anapc16',
#   'Impact',
#   'Mff',
#   'Trim41',
#   'Gtf2a2',
#   'Cct8',
#   'Rpl34-ps1',
#   'Tulp4',
#   'Pml',
#   'Aff4',
#   'Mid1',
#   'Rap2b',
#   'C230081A13Rik',
#   'Ggh',
#   'Fabp1',
#   'Rxra',
#   'Tor1aip2',
#   'Plek',
#   'Dnmt1',
#   'Fermt2',
#   'Nop56',
#   'Spry4',
#   'Fkbp4',
#   'Inpp5a',
#   'Zcchc9',
#   'Zswim6',
#   'Ly6e',
#   'Actb',
#   'Pon2',
#   'Eif4g3',
#   'Mrps14',
#   'Aplp2',
#   'Lsm6',
#   'Mrpl2',
#   'Adam15',
#   'Fth1',
#   'H2afv',
#   'Polr3gl',
#   'Fam117b',
#   'Casp1',
#   'Lrrc8a',
#   'Cnn2',
#   'Dcun1d5',
#   'Safb2',
#   '2410017P09Rik',
#   'Rcbtb2',
#   'Ctnnd1',
#   'Ndufb8',
#   'Add1',
#   'Snrpc',
#   'Hist1h1c',
#   'Prkce',
#   'Sf3b5',
#   'Sacm1l',
#   'Mia3',
#   'Ftl1',
#   'Zfp36l2',
#   'Fus',
#   'Tial1',
#   'Ankrd44',
#   'Zfp362',
#   'Khk',
#   'Ube3c',
#   'Aes',
#   'Kdelc2',
#   'Slu7',
#   'Syngr2',
#   '1500003O03Rik',
#   'Npr1',
#   'Bod1',
#   'Dennd1a',
#   'Akap12',
#   'Obfc2b',
#   'Phf3',
#   'H2-M3',
#   'Ppp1r15b',
#   'Maz',
#   'Eif4e',
#   'Col4a2',
#   'Fgl2',
#   'Ppp2r1a',
#   'Coro1c',
#   'Cdk11b',
#   'Sec13',
#   'Sept7',
#   'Nisch',
#   'Mlx',
#   'Gfpt1',
#   'Eif3a',
#   'Ier5',
#   'Pfdn4',
#   'Mll2',
#   'Aup1',
#   'Tbl1x',
#   'Fut11',
#   'Tbc1d10b',
#   'Rapgef2',
#   'Pgls',
#   'Rnf145',
#   'Tmem50b',
#   'Snrpg',
#   'Prdx4',
#   'Slc39a8',
#   'Insr',
#   'Ccr5',
#   'Pqlc1',
#   'Col13a1',
#   'Sys1',
#   'Dnajc7',
#   'Ssfa2',
#   'Nap1l1',
#   'BC056474',
#   'Sec11c',
#   'Tmed7',
#   'Ate1',
#   'Tspan2',
#   'Apoa2',
#   'Slc25a5',
#   'Gna11',
#   'Mtss1',
#   'Rock1',
#   'Snrpd3',
#   'Zfr',
#   'Mgrn1',
#   'Tbc1d15',
#   'Trio',
#   '2810013P06Rik',
#   'Nrip1',
#   'Mdh1',
#   'Ddrgk1',
#   'Usf2',
#   'Setd5',
#   'Rpn2',
#   'Rbpms',
#   'Cdc42bpb',
#   'Junb',
#   'Vps4b',
#   'Edem2',
#   'Kit',
#   'Adprh',
#   'Srpr',
#   'Ttr',
#   'Ccdc72',
#   'Tpr',
#   'Psmc3',
#   'Rc3h1',
#   'Specc1l',
#   'Cyb5b',
#   'Stx5a',
#   'Chmp7',
#   'C030046I01Rik',
#   'Sdc3',
#   'BC005561',
#   'Hmha1',
#   'March5',
#   'Kbtbd2',
#   'Yif1b',
#   'Mt1',
#   'Snhg3',
#   'C630043F03Rik',
#   'Yeats4',
#   'Wbp11',
#   'Ddost',
#   'Stag2',
#   'Arpc4',
#   '2310003F16Rik',
#   'Ankfy1',
#   '1810046J19Rik',
#   'Ids',
#   'Ptk2',
#   'Tm9sf1',
#   'Ict1',
#   'Dcp2',
#   'Lrrc47',
#   'Iqgap1',
#   'Rhog',
#   'M6pr',
#   'Rock2',
#   'Galntl4',
#   'Phf5a',
#   'Irf2',
#   'Zfp207',
#   'Arhgap29',
#   '2010107H07Rik',
#   'Epn2',
#   'Gpbp1',
#   'Sh2b2',
#   'Cst3',
#   'Akirin2',
#   'Slc4a2',
#   'Pvrl2',
#   'Fmr1',
#   'Rplp0',
#   'Ubqln1',
#   'Zfp322a',
#   'Zrsr2',
#   'Nqo2',
#   'Rbm28',
#   'Srsf1',
#   'Rela',
#   '2310010J17Rik',
#   'Etv5',
#   'Tpi1',
#   'Apbb2',
#   'Cmas',
#   'Cyp26b1',
#   'Mrpl34',
#   'Pole4',
#   'Spty2d1',
#   'Tex264',
#   'Cnot8',
#   'Tsc22d4',
#   'Mitd1',
#   'Tspan31',
#   'Zcchc7',
#   'Csnk1e',
#   'Ube2g2',
#   'E2f4',
#   'Mtmr2',
#   'St3gal6',
#   'Akr1e1',
#   'Ttc28',
#   'Slc35a5',
#   'Senp3',
#   'Hsd17b11',
#   'Rin2',
#   'Tmppe',
#   'Tnfaip2',
#   'Rcbtb1',
#   'Rinl',
#   'Klf13',
#   'Pcnp',
#   'Tnfsf12',
#   'Brwd1',
#   'Luzp1',
#   'Oaz2',
#   'Vps4a',
#   'Prr13',
#   'Igj',
#   'Snrnp40',
#   'Ppp2r5c',
#   'Irf2bp1',
#   'Ets2',
#   'Clec2d',
#   'Csnk2b',
#   'Mepce',
#   'Eci2',
#   'Ttyh3',
#   'Hnrnpf',
#   'Ubr4',
#   'Uqcr10',
#   'Pus1',
#   'Rasgef1b',
#   'Fchsd2',
#   '2700078E11Rik',
#   'Slc48a1',
#   'Cfl2',
#   'Rell1',
#   'Slc30a5',
#   'Chmp1a',
#   'Med10',
#   'Clint1',
#   'Ywhag',
#   'Jund',
#   'Mrps28',
#   '1810006K21Rik',
#   'Eef1d',
#   'Pwwp2b',
#   'Cd302',
#   'Jtb',
#   'Tmem51',
#   'Tmem60',
#   'Mllt10',
#   'Cnot1',
#   'Gns',
#   'Dapk2',
#   'Hcls1',
#   'Sh3bgrl3',
#   'Ndufs5',
#   'Orc3',
#   'Ankrd40',
#   'Apold1',
#   'Tmem160',
#   'Gbp1',
#   'Cant1',
#   'Snx18',
#   'Thap3',
#   'Hdac1',
#   'Gls',
#   'Epb4.1l2',
#   'Pgam1',
#   'Apoe',
#   'Map2k3',
#   'Ssbp4',
#   'Dnajc2',
#   'Ctla2a',
#   'Eif4e3',
#   'Rara',
#   'Rbbp6',
#   'Lzts2',
#   'Serpina3g',
#   'Cat',
#   'Srsf10',
#   'Wtip',
#   'Mbd1',
#   'Mcfd2',
#   'Eltd1',
#   'Cdc42ep5',
#   'Calcrl',
#   'Dyrk1a',
#   'Suds3',
#   'Dad1',
#   'Apoa1',
#   'Ankrd13a',
#   'Sema4c',
#   'Ankra2',
#   'Fh1',
#   'Stx3',
#   'Cd84',
#   'Nkiras2',
#   'Fkbp3',
#   'Lima1',
#   'Atp6v1h',
#   'St3gal5',
#   'Calml4',
#   'Cntfr',
#   'Rab40c',
#   'Peli1',
#   'D8Ertd738e',
#   'Pfn1',
#   'Kcnb1',
#   'Txnrd1',
#   'Vdac3',
#   'Ncbp2',
#   'Psmc6',
#   'Gapvd1',
#   'Commd4',
#   'Usp18',
#   'Plvap',
#   'March2',
#   'Birc6',
#   'Mob2',
#   'Ostc',
#   'Lrmp',
#   'Ubtf',
#   'Epas1',
#   'Cnot3',
#   'Birc2',
#   'Zmym5',
#   'Man1c1',
#   'Slc17a5',
#   'Ppp2r3a',
#   'Ppic',
#   'Rfc1',
#   'Atp2c1',
#   'Efhd2',
#   'Cetn2',
#   'Myd88',
#   'Mospd3',
#   'Mndal',
#   ...],
#  'kupffer': ['Rps27a',
#   'Fau',
#   'Tmsb4x',
#   'B2m',
#   'Cox8a',
#   'Cfl1',
#   'Eef1a1',
#   'Eif1',
#   'Rps3',
#   'Rpl21',
#   'Rpl35',
#   'Aif1',
#   'Gabarap',
#   'H2-D1',
#   'Lamp1',
#   'Rps9',
#   'Rpl9',
#   'Clta',
#   'Ly6e',
#   'Rpl35a',
#   'Fcer1g',
#   'Rac1',
#   'Ctss',
#   'Tceb2',
#   'Rpl15',
#   'Akr1a1',
#   'St3gal5',
#   'Rpl12',
#   'Cd81',
#   'Rpl38',
#   'Rps18',
#   'Erp29',
#   'Atp5e',
#   'Lamp2',
#   'Cybb',
#   'Cox5a',
#   'Actr3',
#   'Tomm6',
#   'Cfp',
#   'Cox6a1',
#   'Pfn1',
#   'Laptm4a',
#   'Rps5',
#   'Acp5',
#   'Malat1',
#   'Eef2',
#   'Serpinb6a',
#   'Cebpb',
#   'Gm11428',
#   'Cst3',
#   'Rpl41',
#   'Bsg',
#   'Nop10',
#   'Slc25a5',
#   'Myl12b',
#   'Pitpna',
#   'Cox7b',
#   'Serf2',
#   'Tomm7',
#   'Gng5',
#   'Ctsh',
#   'Sdcbp',
#   'Sdhb',
#   'Rps29',
#   'Plxnb2',
#   'Srsf9',
#   '1810006K21Rik',
#   'Cyth4',
#   'Mrps21',
#   'Lgals3bp',
#   'Serbp1',
#   'Rnf149',
#   'Rpl37a',
#   'Slc15a3',
#   'C1qa',
#   'Capzb',
#   'Cox5b',
#   'Gapdh',
#   'Tmem59',
#   'Calm2',
#   'Pea15a',
#   'Psap',
#   'St13',
#   '4933407C03Rik',
#   'Mafb',
#   'Atp5g1',
#   'Neat1',
#   'Ctsa',
#   'Timd4',
#   'Fis1',
#   'Apoc1',
#   'Rps26',
#   'Coro1b',
#   'Sepp1',
#   'Lyz2',
#   'Cdc37',
#   'Ndufv3',
#   'Tpd52',
#   'Ubl5',
#   'Vdac2',
#   'Itm2b',
#   'Srp9',
#   'Clec4a3',
#   'Prelid1',
#   'Psmb1',
#   'Ndufb2',
#   'Man2b1',
#   'Aes',
#   'Gnai2',
#   'Hnrnpab',
#   'Fam96a',
#   'Ctsd',
#   'Psmb9',
#   'B4galt6',
#   'Rtn3',
#   'Tomm22',
#   'Atp6v1e1',
#   'Ftl1',
#   'Grn',
#   'Ctsb',
#   'Rnf130',
#   'C1qc',
#   'Cd300a',
#   'Irf2bp2',
#   'Neurl3',
#   'Commd1',
#   'Ly86',
#   'Maf1',
#   'Rabac1',
#   'Mapre2',
#   'Polr1d',
#   'Actb',
#   'Rab32',
#   'Skap2',
#   'Ywhaq',
#   'AB124611',
#   'Rab11a',
#   '4632428N05Rik',
#   'Vsig4',
#   'Tyrobp',
#   'Cct8',
#   'Psmd7',
#   'Arl8b',
#   'Srsf3',
#   'Drap1',
#   'Clec4f',
#   'A430084P05Rik',
#   'Plin2',
#   'Prcp',
#   'Ddx5',
#   'Rap1b',
#   'Ucp2',
#   'Cbx3',
#   'Anp32b',
#   'Pnrc1',
#   'Hspe1',
#   'Selk',
#   'Ociad1',
#   'Ubb',
#   'Hist1h2bc',
#   'Cadm1',
#   'Sf3b2',
#   'Sf3b5',
#   'Ndufa3',
#   'Cisd2',
#   'Psmb5',
#   'Ccdc72',
#   'Psma4',
#   'Ndufb5',
#   'Mtch1',
#   'Ctdsp1',
#   'Kif5b',
#   'Hexa',
#   'Sf3b1',
#   'Vasp',
#   '1810046J19Rik',
#   'Grb2',
#   'C1qb',
#   'Plekhb2',
#   'Sepw1',
#   'Peli1',
#   'Fuca2',
#   'Psmg4',
#   'Jak1',
#   'Ifnar2',
#   'Myeov2',
#   'Tmed7',
#   'Bola2',
#   'Rab10',
#   'Uqcrfs1',
#   'Ndufab1',
#   'Adipor1',
#   'AF251705',
#   'Arpc2',
#   'Igsf6',
#   'Morf4l1',
#   'Rtn4',
#   'Prdx2',
#   'Slc25a39',
#   'Psmb7',
#   'Gltp',
#   'Vav1',
#   'Mfsd5',
#   'Eif3c',
#   'Cycs',
#   'Csf2ra',
#   'Nagk',
#   'Mrpl52',
#   'Zfp467',
#   '5031439G07Rik',
#   'Vamp5',
#   'Tep1',
#   'Rbm7',
#   '2900010M23Rik',
#   'Dnase2a',
#   'Higd2a',
#   'Lgmn',
#   'Sumo3',
#   'Hspa9',
#   'Ube2d3',
#   'Sar1a',
#   'Ran',
#   'Ifngr2',
#   'Itm2c',
#   'Icam1',
#   'Eif4a2',
#   'Cacybp',
#   'Atp6ap2',
#   'Psmd8',
#   'Tsc22d3',
#   'Psma5',
#   'Polr2l',
#   '3110003A17Rik',
#   'Hsd17b10',
#   'Sepx1',
#   'Hsd17b12',
#   'Cndp2',
#   'Fkbp2',
#   'Syk',
#   'Rtp4',
#   'Mbnl1',
#   'Serinc3',
#   'Sft2d1',
#   'March5',
#   'Fam111a',
#   'Pon2',
#   'Apoe',
#   'H2-Ke2',
#   'Arpc1a',
#   'Sin3b',
#   'Arl8a',
#   'Dusp3',
#   'Folr2',
#   'Rbm17',
#   'Cd5l',
#   'H2-DMb1',
#   'Creg1',
#   'Ptpn6',
#   'Eif5',
#   'Hsp90aa1',
#   'Ptpn1',
#   'Ccdc12',
#   'Cope',
#   'Glud1',
#   'Cd53',
#   'Mrp63',
#   'Treml4',
#   'C030046I01Rik',
#   'Rps28',
#   'Vps28',
#   'Clptm1l',
#   'Cdc42',
#   'Ctdnep1',
#   'Sirpa',
#   'Pin4',
#   'Stard3nl',
#   '9030624J02Rik',
#   'Nhp2l1',
#   'Ndufs4',
#   'Pofut2',
#   'Rgs2',
#   'Canx',
#   'Wdr1',
#   'Ckb',
#   'Laptm5',
#   'Idh3b',
#   'Gpx4',
#   'Marcks',
#   'Zfp706',
#   'Lst1',
#   'Paip2',
#   'Rnf115',
#   'Strap',
#   'Srsf5',
#   'Slc29a1',
#   'Slc7a8',
#   'Ctbp1',
#   'Fabp7',
#   'Psmb6',
#   'Tcf25',
#   'Sys1',
#   'Elovl1',
#   'Prkcb',
#   'Abi1',
#   'Pgd',
#   'Evi2b',
#   'Tmem160',
#   'Wnk1',
#   'Usf2',
#   'Son',
#   'Maf',
#   'Mpeg1',
#   'Fam63b',
#   'Pilrb2',
#   'Hat1',
#   'Hsd17b11',
#   'Cct7',
#   'Park7',
#   'Srrm2',
#   'Atp1b3',
#   'Dynlt3',
#   'Fam108a',
#   'Ube2q1',
#   'Rhoa',
#   'Hcst',
#   'Med30',
#   '1110058L19Rik',
#   'Ncoa4',
#   'B3gat3',
#   'Usp19',
#   'Rnf139',
#   'Xrn2',
#   'Ssr1',
#   'Sfpi1',
#   'Naaa',
#   'Aldh2',
#   'Aip',
#   'Pgam1',
#   'Fez2',
#   'Ms4a8a',
#   'Fcgrt',
#   'Unc93b1',
#   'Aplp2',
#   'Lgals9',
#   'Churc1',
#   'Ifi47',
#   '5430435G22Rik',
#   'Nrp1',
#   'Sec13',
#   'Bak1',
#   'Pml',
#   'Gusb',
#   'Rp9',
#   'Scp2',
#   'Ilk',
#   'Arf6',
#   'Irf7',
#   'Trim26',
#   '2310004N24Rik',
#   'Ccl6',
#   'Cisd1',
#   'Csf3r',
#   'Acin1',
#   'Eny2',
#   'Ilkap',
#   'Il18bp',
#   'Eif3i',
#   'Cebpa',
#   'Lipa',
#   'Wbp2',
#   'Fkbp15',
#   'Mrps23',
#   'Basp1',
#   '1810009A15Rik',
#   'Nr1h3',
#   'Rhog',
#   'Csf1r',
#   '2810004N23Rik',
#   'Fgfr1op2',
#   'Cklf',
#   'Actr2',
#   'Rbbp6',
#   'Picalm',
#   'Aga',
#   'Pcna',
#   'Zfand3',
#   'Plekho2',
#   'Aamp',
#   'Mrpl43',
#   'Psmc4',
#   'Klf10',
#   'Limd1',
#   'Sept7',
#   'Nfkbia',
#   'Dram2',
#   'Cct5',
#   'Gm561',
#   'Cdc42se1',
#   'Cd300e',
#   'Trim30a',
#   'Arl4c',
#   'Glo1',
#   'Tbcb',
#   'Zbtb7a',
#   'Zcrb1',
#   'Ppp4c',
#   '2510006D16Rik',
#   'Psmb4',
#   'Arhgap17',
#   'Copb2',
#   'Rbck1',
#   'Xdh',
#   'Akap13',
#   '2310044H10Rik',
#   'Timp2',
#   'Ski',
#   'Zbtb4',
#   'Anxa3',
#   'Dnaja1',
#   'Trp53',
#   'Hprt',
#   'Gas5',
#   'Sec14l1',
#   'Ifit2',
#   'Lrp6',
#   'Clec4a1',
#   'Snap23',
#   'Fam162a',
#   'Mrpl2',
#   'Tcp1',
#   'Npm1',
#   'Vapa',
#   'Phc2',
#   'Amfr',
#   'Jdp2',
#   'Ccr5',
#   'Pcbd2',
#   'Dcxr',
#   'Cir1',
#   'Fam103a1',
#   'Abhd12',
#   'Hdac2',
#   'Kctd12',
#   'Tgfbr2',
#   'Itgal',
#   '2510039O18Rik',
#   'Arhgap30',
#   'Eif3h',
#   'Ifih1',
#   'Hbegf',
#   'Aimp1',
#   'Ncstn',
#   'Hpgd',
#   'Rrp1',
#   'Tmed2',
#   '2400003C14Rik',
#   'Lfng',
#   '5033414D02Rik',
#   'Suclg1',
#   'Tax1bp1',
#   'Sirt2',
#   'Chrac1',
#   'Yy1',
#   'Wdr41',
#   'Irf9',
#   'Hibadh',
#   'Lcp2',
#   'Trappc6b',
#   'Stx4a',
#   'Btf3l4',
#   'Elf1',
#   'Mlf2',
#   'Unc119',
#   'Cpne2',
#   'Psmd6',
#   'Imp3',
#   'Baz1a',
#   'Herc4',
#   'Ndufb11',
#   'Chmp1b',
#   'Pkp4',
#   'Lyz1',
#   'Msl1',
#   'Pip4k2a',
#   'Gm2a',
#   'Herc6',
#   'Nlrp3',
#   'Mrc1',
#   'Eed',
#   'Ptgs1',
#   'Ssr4',
#   'Cd300ld',
#   '2610002M06Rik',
#   'Elmo2',
#   'Dohh',
#   'Pkib',
#   'Mrpl12',
#   'B230219D22Rik',
#   'Nol7',
#   'Copa',
#   'Igf1',
#   'Cebpg',
#   'Crip1',
#   'Ogfrl1',
#   'Kars',
#   'Tm6sf1',
#   'Nmi',
#   'Ssb',
#   'Gtf2h5',
#   'Cdipt',
#   'Gbf1',
#   'Skil',
#   'Thrap3',
#   'Lilra5',
#   'Il17ra',
#   'Lrrc58',
#   'Emr1',
#   'Prpf19',
#   'Tex264',
#   'Cox4nb',
#   'Rnf181',
#   '2010109K11Rik',
#   'Mbnl2',
#   'Coro1c',
#   'C3ar1',
#   'Gngt2',
#   'Irf1',
#   'Ankrd13a',
#   'Rps6ka1',
#   'Pcnp',
#   'Gmip',
#   'Slc25a4',
#   'Scarb1',
#   'Mrps11',
#   'Commd2',
#   '2210016L21Rik',
#   'Shkbp1',
#   'Cmklr1',
#   'Axl',
#   'Smpdl3a',
#   'Igbp1',
#   'Fam100b',
#   'Phb2',
#   'Spag7',
#   'Wdr26',
#   'Gpcpd1',
#   'Inpp5d',
#   'Emilin2',
#   'Fam49a',
#   'Bbip1',
#   'Dync1h1',
#   'Tnpo2',
#   'Trappc5',
#   'Nrbf2',
#   'Gsk3b',
#   'Stk40',
#   'Secisbp2l',
#   'Trim30d',
#   'Pnp',
#   'Gnl1',
#   'Snx25',
#   'Abl1',
#   'Pafah1b2',
#   'Atp6v0b',
#   'P2ry12',
#   'Rnh1',
#   'Siglece',
#   'Tardbp',
#   'Mbd3',
#   '2310009A05Rik',
#   'Tbc1d5',
#   'Eif3l',
#   'Shisa5',
#   'H1f0',
#   'Ncl',
#   'Cd82',
#   'Cnbp',
#   'Jkamp',
#   'Tor1a',
#   'Hip1',
#   'Oasl2',
#   'Npc1',
#   'Vim',
#   'Gtf3a',
#   'Ehmt2',
#   'Dse',
#   'Sh3bp2',
#   'Glipr1',
#   'Hist1h1c',
#   'Apoa1bp',
#   'Txnl1',
#   'Vps4a',
#   'Sp3',
#   'Manbal',
#   'Mkln1',
#   'Oaz2',
#   'Lyn',
#   'Tubb2a',
#   'Rock2',
#   'Rcsd1',
#   'Dph3',
#   'Cyb5r4',
#   'Lsm6',
#   'Pdcl3',
#   'Ap4s1',
#   'Coq9',
#   '9430038I01Rik',
#   'Mapk14',
#   'Nuak2',
#   'Pla2g7',
#   'Tspo',
#   'Mapkapk5',
#   'Scarb2',
#   'Csnk2a1',
#   'Pisd',
#   'Seh1l',
#   'Cd97',
#   'Akirin1',
#   'Mrpl32',
#   'Dus1l',
#   'Tax1bp3',
#   'Ncoa1',
#   'Tspan17',
#   'Sympk',
#   'Adrbk1',
#   '1810063B07Rik',
#   'Zbp1',
#   'Ctso',
#   'Dlst',
#   'Acads',
#   'St3gal4',
#   'Erp44',
#   'Ehbp1l1',
#   'Vars',
#   '1700012B15Rik',
#   'Mfap3',
#   'Gclm',
#   'Magoh',
#   'Setd8',
#   'Rnf146',
#   'Sdf2l1',
#   'Cd44',
#   'Kdm5a',
#   'Ube2a',
#   'Bet1l',
#   'Utp3',
#   'Gpx1',
#   '2810021B07Rik',
#   'Pla2g15',
#   'Mecp2',
#   'Tom1',
#   'Tlr7',
#   'Gmpr2',
#   'Ppdpf',
#   'Fam167a',
#   'Rel',
#   'Ndufv1',
#   'Psmd12',
#   'Zdhhc14',
#   'Oas2',
#   'Slc7a7',
#   'Wdfy4',
#   'Pik3r1',
#   'Pla2g16',
#   'Armc1',
#   'Nudt2',
#   'Ubxn4',
#   'Nip7',
#   'Man2a1',
#   '9030625A04Rik',
#   'Plek',
#   'Dscr3',
#   'Smarcb1',
#   'Csk',
#   'Dapk1',
#   'C330006A16Rik',
#   'Rps27',
#   'Keap1',
#   'Trim28',
#   'Rfwd2',
#   'Gbp8',
#   'Atp5k',
#   '2810405K02Rik',
#   'Ncf4',
#   'Btbd9',
#   'Gna13',
#   'Leng8',
#   'Arap1',
#   'Gemin7',
#   'Stard8',
#   'AA960436',
#   'Wipf1',
#   'Ost4',
#   'Ppp3r1',
#   'Mrps34',
#   'Dgat1',
#   'Fam3c',
#   'Man1b1',
#   'Fundc2',
#   'Fbxo32',
#   'Rasgrp2',
#   'Lrp1',
#   'Emr4',
#   'Tmem128',
#   'Cdk2ap2',
#   'Tpp1',
#   'Smarcd2',
#   'Ids',
#   'Rce1',
#   'Prpf8',
#   'Sec11c',
#   'Cr1l',
#   'R3hdm2',
#   'Plaa',
#   'Mtus1',
#   'Nr2c2ap',
#   'Nptn',
#   'Sult1a1',
#   'Mrpl48',
#   'Pole4',
#   'D19Ertd737e',
#   'Ifi27l2a',
#   'Adam10',
#   'Hdac1',
#   'Ythdf2',
#   'Ppp1r18',
#   'Zfand6',
#   'Rab11b',
#   'Isy1',
#   'Med21',
#   'Tnrc6b',
#   'Snrnp70',
#   'Dmpk',
#   'Phactr2',
#   'Selplg',
#   'Cmtm6',
#   'Ak2',
#   'Psmc6',
#   'Clec4n',
#   'Rap2c',
#   'Galnt1',
#   'Nsmce2',
#   'Pkn2',
#   '2210403K04Rik',
#   'Tagln2',
#   'Ndel1',
#   'B430306N03Rik',
#   'Ube2k',
#   'Taok1',
#   'Nfic',
#   'I830077J02Rik',
#   'Mif',
#   'Sipa1',
#   'Tm2d3',
#   'B4galt1',
#   'Snx17',
#   'Pkm2',
#   'Fcna',
#   'Usp12',
#   'Adnp',
#   'AI314976',
#   'Stx3',
#   'Htatip2',
#   'Ssh2',
#   'Cpsf2',
#   'Unc50',
#   'Asph',
#   'Tra2a',
#   'Herc1',
#   'B230378P21Rik',
#   'Nacc1',
#   'Scyl1',
#   'Foxn3',
#   'Brpf1',
#   'Mrpl20',
#   'Actn1',
#   'Samm50',
#   'Il10rb',
#   'Atp11c',
#   'BC003266',
#   'P2ry13',
#   'Tsnax',
#   'Ptplb',
#   'Rinl',
#   'Blmh',
#   'Aagab',
#   '2010003O02Rik',
#   'Mea1',
#   'Mcts1',
#   'Limd2',
#   'Dcaf13',
#   'Ttc7',
#   'Brd3',
#   'Snx4',
#   'Mink1',
#   'Plekhj1',
#   'Sgpl1',
#   'Rala',
#   'Baz2b',
#   'Entpd1',
#   'B3gnt1',
#   'Fkbp3',
#   'Ppil3',
#   'Hras1',
#   'Lars',
#   '1700123O20Rik',
#   'Ormdl2',
#   'Il10ra',
#   'Pnpla2',
#   'Tmem86a',
#   'Ppp6r3',
#   'Huwe1',
#   'Hltf',
#   'Fem1c',
#   'Mtap1s',
#   'Eif2a',
#   'E030024N20Rik',
#   'Slc25a33',
#   'Rnf187',
#   'Minpp1',
#   'Extl3',
#   'Pcm1',
#   'Dld',
#   'Mrpl44',
#   'Spcs2',
#   'Dpp7',
#   'Rbm25',
#   'Ndufs8',
#   'X99384',
#   'Aoah',
#   'Tmem106c',
#   'Pdlim5',
#   'Mpp1',
#   'Sp140',
#   'Kif1b',
#   'Pilrb1',
#   'Naa10',
#   'Add1',
#   'Rab8b',
#   'Pten',
#   'Ppp2r5e',
#   'Mrps25',
#   'Pigq',
#   'Tmem203',
#   'Zhx1',
#   'Acp2',
#   'Siglec1',
#   'Zdhhc18',
#   'Klf13',
#   'Hcfc1',
#   'Etv6',
#   'Ypel5',
#   'Fam125a',
#   'Celf2',
#   'Copg',
#   'Phf21a',
#   'Tmem87b',
#   '1810022K09Rik',
#   '2900092E17Rik',
#   'Ap3d1',
#   'Mgrn1',
#   'Rrp8',
#   'Thoc7',
#   '2310008H09Rik',
#   'Hiat1',
#   'Cab39',
#   'Fdx1',
#   'Lrrk1',
#   'Rxra',
#   'Grk6',
#   'Shmt2',
#   'Mid1ip1',
#   'Snx10',
#   'Bud31',
#   '2310035K24Rik',
#   'Bag5',
#   'Arih2',
#   'Pigs',
#   'Ypel3',
#   'Fam176b',
#   'Nucb2',
#   'Nomo1',
#   'Btaf1',
#   'Slc12a6',
#   'Zfp90',
#   'Pbx2',
#   'Eif1b',
#   'Ric8',
#   'Myo9b',
#   'Uba7',
#   'Cdh5',
#   'Tsc2',
#   'Stard3',
#   'Chordc1',
#   'Mtap',
#   'Rmnd5b',
#   'Adcy3',
#   'Msl2',
#   'Eif4e',
#   'Scaf11',
#   'Ptpra',
#   'Sdc3',
#   'Pltp',
#   '2310040G24Rik',
#   'Stat6',
#   'Cd79b',
#   'Pilra',
#   'Agpat3',
#   'Odc1',
#   'Ptpmt1',
#   'Dctn5',
#   'Zfp787',
#   'Dnajb1',
#   'Galc',
#   'Ptdss1',
#   'Pxmp4',
#   'Ppa1',
#   'Jup',
#   'Faf1',
#   'Nudt16l1',
#   'Cse1l',
#   'Lats1',
#   'Trnau1ap',
#   'Cstf3',
#   'Pitpnm1',
#   'Eif3g',
#   'Nipbl',
#   'Wbp1',
#   'Map2k1',
#   'Pih1d1',
#   'Mrpl50',
#   'Cdkn1b',
#   'Rilpl2',
#   'Itfg3',
#   '1600010M07Rik',
#   'Mcee',
#   'Pdgfb',
#   'Zyx',
#   '4933433P14Rik',
#   'Tpcn2',
#   'Mcm3',
#   'Stard5',
#   'Eif3d',
#   'Stk17b',
#   'Ptprj',
#   'Ergic2',
#   'Vps72',
#   'Cdk19',
#   'Suz12',
#   'Slfn8',
#   'Enox2',
#   'Fem1b',
#   'Ss18',
#   'Fdps',
#   'Baz1b',
#   'Sgk1',
#   'Pisd-ps3',
#   'Insr',
#   '2210012G02Rik',
#   'Wdr48',
#   'Hadhb',
#   'Ctnnd1',
#   'Smarca4',
#   'Bcl7c',
#   'Eri3',
#   'Cops5',
#   'Pde4b',
#   'Ppm1h',
#   'Wtap',
#   'Ap2b1',
#   'Pxmp3',
#   'Tmem188',
#   'Epn1',
#   'Ankrd40',
#   'Jun',
#   'Tmem223',
#   'Rell1',
#   'Uxt',
#   'Aarsd1',
#   'Vps25',
#   'Tbrg1',
#   'Mast3',
#   'Sbds',
#   'Serinc1',
#   'Patl1',
#   'Tmcc3',
#   'Gpr108',
#   'Sla',
#   'Ptcd3',
#   'Tmem140',
#   'Acot9',
#   'D14Ertd668e',
#   'Vkorc1',
#   'Upf2',
#   'Gm6377',
#   'Rabggtb',
#   'Tmem50b',
#   'Rbm5',
#   'Zfp932',
#   'Setx',
#   ...],
#  'hepatic_stellate': None,
#  'NK': ['H2-D1',
#   'Ms4a4b',
#   'Rpl28',
#   'Fth1',
#   'Cd3d',
#   'Myl6',
#   'Hspa8',
#   'Sec61g',
#   'Rps28',
#   'Ube2d3',
#   'Arpc2',
#   'Ms4a6b',
#   'Cdc42',
#   'Cfl1',
#   'Rac2',
#   'Hnrnpa2b1',
#   'Pfn1',
#   'Rbx1',
#   'S100a10',
#   'Ubb',
#   'Serf2',
#   'Gng5',
#   'Arhgdib',
#   'Psmb1',
#   'Calm2',
#   'Tmsb10',
#   'Ctsw',
#   'Ldha',
#   'Cox7a2',
#   'Epsti1',
#   'Ftl1',
#   'Rps27',
#   'Gimap3',
#   'Lime1',
#   'Ptpn22',
#   'Shisa5',
#   'Sep15',
#   'Cd47',
#   '1810037I17Rik',
#   'Nedd8',
#   'Hspa5',
#   'Gimap4',
#   'Eef1b2',
#   'Tspo',
#   'Ost4',
#   'Lrrc58',
#   'Actb',
#   'Dynll1',
#   'Cwc15',
#   'Eif3g',
#   'Selplg',
#   'Cope',
#   'Eif5a',
#   'Tomm22',
#   'Prdx6',
#   'Minos1',
#   'Tapbp',
#   'Wdr1',
#   'Psme1',
#   'Sfpq',
#   'Actr2',
#   'Nop10',
#   'Klf13',
#   'Rap1b',
#   'Usmg5',
#   'Prr13',
#   'Sh3bgrl3',
#   'Ube2v1',
#   'Grcc10',
#   'Ppp1ca',
#   'Fyb',
#   'Ier3ip1',
#   'Cdk2ap2',
#   'Zfp36l2',
#   'Hcls1',
#   'Cox6a1',
#   'Sf1',
#   'Hspe1',
#   'Arf1',
#   'Cnp',
#   '1810006K21Rik',
#   'Fgfr1op2',
#   'Itgal',
#   'Tmed2',
#   'Srsf5',
#   'Spcs2',
#   'Psmb9',
#   'Pgk1',
#   'Ccnd2',
#   'Prkar1a',
#   'Pafah1b1',
#   'Arpc5',
#   'Lsm5',
#   'Hsp90ab1',
#   'Vdac2',
#   'Vps28',
#   'Rnf166',
#   'Csk',
#   'Hdac1',
#   'Arhgdia',
#   'Vim',
#   'Mrpl23',
#   'Snrpd2',
#   'Mrps21',
#   'Maf1',
#   'Lamp1',
#   'Stra13',
#   'Tgfb1',
#   'Peli1',
#   'Cnn2',
#   'Cd37',
#   'Stk4',
#   'Fkbp8',
#   'Ltb',
#   'Grap',
#   'Polr2m',
#   'Sept1',
#   'Mrps33',
#   '2310044H10Rik',
#   'Churc1',
#   'Stk24',
#   'Sept7',
#   'Plekha2',
#   'Irf1',
#   'Rbm3',
#   'Cuta',
#   'Aup1',
#   'Lrmp',
#   'Tprgl',
#   'Aprt',
#   'Psmb10',
#   'Mrps24',
#   'Zfp706',
#   'Higd2a',
#   'Atf4',
#   'Aamp',
#   'Scand1',
#   'Dpy30',
#   'Tagln2',
#   'AI462493',
#   'Cxcr6',
#   'Denr',
#   'Brp44',
#   'Nfkbia',
#   'Capzb',
#   'Spn',
#   'Fam165b',
#   'Apbb1ip',
#   'Ranbp1',
#   'Rps15a-ps6',
#   'Nars',
#   'Serinc3',
#   'Nucb1',
#   'Id2',
#   'Commd4',
#   'Cct5',
#   'Grb2',
#   'Ablim1',
#   'Ccdc124',
#   'Tmod3',
#   'Myeov2',
#   'Fam195b',
#   'Pdcd4',
#   'Psma4',
#   'Tm9sf3',
#   'Apobec3',
#   'Bst2',
#   'Fbxw2',
#   'Ggnbp2',
#   'Ndufb4',
#   'Plekhj1',
#   'Anapc11',
#   'Krtcap2',
#   'Zbp1',
#   'Rbm17',
#   'Polr1d',
#   'Cmc1',
#   'Exosc3',
#   'Plcxd2',
#   'Txnl1',
#   'Iqgap1',
#   'Serpina3g',
#   'Dnajc9',
#   'Purb',
#   'Prorsd1',
#   'Ssbp4',
#   'D10Wsu52e',
#   'Tecr',
#   'Dcps',
#   'Ppig',
#   'D11Wsu99e',
#   'Lrp10',
#   'Ube2d2',
#   'Mrps36',
#   'Itga4',
#   'Tap1',
#   'Srsf11',
#   'Drap1',
#   'Gm16517',
#   'Mak16',
#   'Polr2l',
#   'Ly6e',
#   'Tomm20',
#   'Ier5',
#   'Gpbp1',
#   'Ndufa3',
#   'Hdgfrp2',
#   'Eif3a',
#   'Sdcbp',
#   'Rbmxl1',
#   'Ptbp1',
#   'Tmem219',
#   'Slc38a2',
#   'Qars',
#   'Rsrc2',
#   'Ikzf1',
#   'Il2rb',
#   'Kif5b',
#   'Aes',
#   'Matr3',
#   'Mia3',
#   'Tuba1a',
#   'Sars',
#   'Tcp1',
#   'Gadd45gip1',
#   'Max',
#   'Rbm7',
#   'Nipsnap3b',
#   'Ccar1',
#   'E2f4',
#   'Prkag1',
#   'Ctdsp1',
#   'Lbh',
#   'Mcts1',
#   'Myo1f',
#   'Use1',
#   'Cdk4',
#   '2810008M24Rik',
#   'Uqcrq',
#   'Ypel3',
#   'P2ry10',
#   'Sf3b4',
#   'Rpp21',
#   'Prkch',
#   'Vapa',
#   'Dync1i2',
#   'Elf1',
#   'Vbp1',
#   '2410006H16Rik',
#   'Acaa1a',
#   'Mrps18a',
#   'Eif3m',
#   'Ddx19a',
#   'Sra1',
#   'Phb2',
#   'Atpif1',
#   'Atf1',
#   '2310003F16Rik',
#   'F2r',
#   'Metrnl',
#   'St3gal6',
#   'Drg1',
#   'Gmps',
#   'Egln2',
#   'Polr2j',
#   'Tomm5',
#   '2810428I15Rik',
#   'Sema4a',
#   'Rps15a-ps4',
#   'Eif4g1',
#   'Klrk1',
#   'Psap',
#   'Zap70',
#   'Gtf2f1',
#   'Chmp3',
#   'Fam96b',
#   'Cep110',
#   'Dnajb11',
#   'Tomm40',
#   'Bcl7b',
#   'Unc13d',
#   'Thy1',
#   'Wbp11',
#   'Prdx3',
#   'Runx3',
#   'Slc50a1',
#   'Nsmce2',
#   'Tsg101',
#   'Med4',
#   'Clns1a',
#   'Xcl1',
#   'Got2',
#   'Tax1bp1',
#   'Lamtor2',
#   'Itk',
#   'Rab18',
#   'Wbp1',
#   'Nmi',
#   'Mll5',
#   'Esco1',
#   'Anxa7',
#   'Smc1a',
#   'Capza2',
#   'Smap2',
#   'Sms',
#   'Wnk1',
#   'Cdc5l',
#   'Mllt6',
#   'N4bp2l2',
#   'Pdia4',
#   'Trappc4',
#   'Plac8',
#   'Celf2',
#   'Cul3',
#   'Ube2q1',
#   'Shkbp1',
#   'Txn1',
#   'Ino80b',
#   'Rabgap1l',
#   'Prpf40a',
#   'Cdk17',
#   'Ppp2r2a',
#   'Tmem59',
#   'Irf2',
#   'Gabarapl2',
#   'Itgb2',
#   'Tsnax',
#   'Poldip2',
#   '2810021B07Rik',
#   'Ubl4',
#   'BC017612',
#   'Gpsm3',
#   'Cyb5',
#   'Rab9',
#   'Fundc1',
#   'Serinc1',
#   'Cct7',
#   'Txndc17',
#   'Ube2j1',
#   'Ndfip1',
#   'Isyna1',
#   'Tpp2',
#   'Pak2',
#   'Dpm3',
#   'Slc39a7',
#   '5133401N09Rik',
#   '2310011J03Rik',
#   'Tram1',
#   'Cdc42se1',
#   'Rab37',
#   'Cxxc1',
#   'Tcf25',
#   'Twf2',
#   'Rnf187',
#   'Hmg20b',
#   'Arl4c',
#   'Prex1',
#   'Irf9',
#   'C1qbp',
#   'Yipf5',
#   'Nsfl1c',
#   'Stk11',
#   'Mdp1',
#   'Gbp7',
#   'Ly6c2',
#   'Dnajc14',
#   'Hspd1',
#   'Fyttd1',
#   'Gtf2h5',
#   'Dnajc3',
#   'Mthfd2',
#   'Txndc9',
#   'Eri1',
#   'Klrd1',
#   'Arf3',
#   'Tmem71',
#   'Icam1',
#   'Sap30l',
#   'Hnrnpl',
#   'Dnajc19',
#   'Stk16',
#   'Tor1a',
#   'Asf1a',
#   'Glo1',
#   'Fam46a',
#   'Frmd8',
#   'Oaz2',
#   'Nt5c',
#   'Pnn',
#   'Lyar',
#   'Sf3b1',
#   'Krcc1',
#   'Tgfbr2',
#   'Mcmbp',
#   'Trim26',
#   'Tsc22d4',
#   'Ubxn6',
#   'Lfng',
#   'Gimap5',
#   'Arl2bp',
#   'Wbp5',
#   'Josd2',
#   'Txk',
#   'Glud1',
#   'Top1',
#   'Fibp',
#   'Med9',
#   'Mrpl27',
#   'Ilf2',
#   'Prkca',
#   'Impdh1',
#   'Prrc2c',
#   'Exosc8',
#   'Lypla2',
#   'Parvg',
#   'Gstp1',
#   'Vps37b',
#   'Tspyl1',
#   'Hnrnpm',
#   'Gm15421',
#   'Clint1',
#   'Gata3',
#   'Psen1',
#   'Rock1',
#   'Mndal',
#   'Cept1',
#   'Snx17',
#   '1110038F14Rik',
#   'Hist1h1e',
#   'Chn2',
#   'Sdhaf1',
#   'Ndufc1',
#   'Tpr',
#   'Suds3',
#   'Triobp',
#   'Taf15',
#   'Tmed9',
#   'Pak1ip1',
#   'Srf',
#   'Nfatc3',
#   'Gfpt1',
#   'Acadl',
#   'Sbno1',
#   'Rasgrp1',
#   'Tmem37',
#   'Pfkl',
#   'Sh3glb1',
#   'Ppp1r9b',
#   'Armc1',
#   'Ddx46',
#   'Arsb',
#   'Cd27',
#   'Mll3',
#   'Baz1b',
#   'Zdhhc6',
#   'Chtf8',
#   'Polr2k',
#   'Cacybp',
#   'Kdelr2',
#   'Cat',
#   'Thap11',
#   'Fxr1',
#   'Rhoh',
#   'Arrb2',
#   'Fam102a',
#   'Cobra1',
#   'Pxn',
#   'Psme3',
#   'Gosr2',
#   'Gorasp2',
#   'Usf2',
#   'H2-M3',
#   'Ppp1r2',
#   'Rsbn1',
#   'Mrps26',
#   'Sp3',
#   'Acadm',
#   'Gpr174',
#   'Spg21',
#   'Pin4',
#   'Wdtc1',
#   'Thoc3',
#   'Gyg',
#   '2610101N10Rik',
#   '9130011J15Rik',
#   'Cmtm7',
#   'Wipf1',
#   'Zyx',
#   'Csnk1g2',
#   'Atg4d',
#   'Nptn',
#   'Mlf2',
#   'Fam89b',
#   'Mrpl15',
#   'Bzw2',
#   'Tpd52l2',
#   'Tnfrsf1a',
#   'Xaf1',
#   'Surf1',
#   'Idh3a',
#   'Lass5',
#   'Dusp2',
#   '0610007L01Rik',
#   'Efha1',
#   'Spryd3',
#   'Nde1',
#   'Rab19',
#   'Scp2',
#   'Rbm26',
#   'Il2rg',
#   'Elf4',
#   'AI467606',
#   'Stk19',
#   'Rad50',
#   'Canx',
#   'Stip1',
#   'Gps2',
#   'Arih1',
#   'Laptm4a',
#   'Mir703',
#   'Reep3',
#   'Socs1',
#   'H2-DMa',
#   'Atp5k',
#   'Ptpn6',
#   'Ppp2r1a',
#   'Pde3b',
#   'Cpsf6',
#   'Iscu',
#   'Rnaseh2c',
#   'Chrac1',
#   'P4hb',
#   'Slmap',
#   'Hsd17b12',
#   'Gpr108',
#   'Chd1',
#   'Ccdc115',
#   'Gpaa1',
#   'Oaz1',
#   'Arhgap9',
#   'Slc38a10',
#   'Ufc1',
#   'Fli1',
#   'Tomm34',
#   'Ilk',
#   'Gramd1a',
#   'Cmtm6',
#   'Klf6',
#   'Med8',
#   'Tmem147',
#   'Ash1l',
#   'Pqlc3',
#   'Wdr89',
#   'Zfand2b',
#   'Brcc3',
#   'Nop58',
#   'Agfg1',
#   'Akirin1',
#   'BC013529',
#   '2900097C17Rik',
#   'Pdcd7',
#   'Npm3-ps1',
#   'Arhgef1',
#   'Irf8',
#   'Sept9',
#   'Zdhhc21',
#   'Adsl',
#   'Ppa2',
#   'Slc25a39',
#   'Pgrmc1',
#   'Gnptg',
#   'Rap2c',
#   'Ssr1',
#   'Smad7',
#   'Herpud2',
#   'Gna13',
#   'Cnot4',
#   'Alg1',
#   'Rnf181',
#   'Hnrnph1',
#   'Sytl2',
#   'Stx4a',
#   'Madd',
#   'Arl8a',
#   'Ankrd12',
#   'Dap',
#   'Stk39',
#   '0610037L13Rik',
#   'Sytl3',
#   'Dok2',
#   'N4bp2l1',
#   'B230219D22Rik',
#   'Trim30a',
#   'Dcaf8',
#   'Ccng2',
#   'Polr2h',
#   'Abcf2',
#   'Nr1h2',
#   'Tmem192',
#   'Arpc5l',
#   'Acap1',
#   'Vars',
#   'Ppp3cc',
#   'Tes',
#   'Txlna',
#   'Cbx3',
#   'Scamp2',
#   'Itgb7',
#   'Myst3',
#   'Prkcz',
#   'U2af1l4',
#   'Zfp106',
#   'Mtx2',
#   'Donson',
#   'H47',
#   'Atp6ap2',
#   'Nufip2',
#   'Cltc',
#   'Metap2',
#   'Meaf6',
#   'Ctdnep1',
#   'Dnajb1',
#   'Kcnab2',
#   'Xiap',
#   'Stk40',
#   'Mrpl13',
#   'Slc25a4',
#   'Pelo',
#   'Atrx',
#   'Hras1',
#   'Asl',
#   'Irf3',
#   'Wdr33',
#   'Nup35',
#   'Creg1',
#   'Exoc5',
#   'Gfi1',
#   'Rrp7a',
#   'Hdhd2',
#   'Ifi35',
#   'Fam32a',
#   'Ipcef1',
#   'Dnaja1',
#   'Pafah1b2',
#   '9030624J02Rik',
#   'Ufd1l',
#   'Fbxo22',
#   'Ttc32',
#   'Eef1e1',
#   'Get4',
#   'Znrd1',
#   'Rassf2',
#   'Zfp524',
#   'Yrdc',
#   'Alkbh3',
#   'Fam105a',
#   'Cxx1c',
#   'Ncbp2',
#   'Rpn1',
#   'Ifitm3',
#   'Sp2',
#   'Gtf2h3',
#   'Anxa11',
#   'Mospd3',
#   'Samhd1',
#   'Atad2',
#   'Nit2',
#   'Iws1',
#   'Fastk',
#   'Ppp1r11',
#   'Exosc5',
#   'Smchd1',
#   'Ppp1r18',
#   'Tra2a',
#   'Inpp5k',
#   'Sap18',
#   'Lmf2',
#   'Osgep',
#   'Mlx',
#   'Rrn3',
#   'Exosc6',
#   'Baz2a',
#   'Zfp36',
#   'Slc20a1',
#   'Mrpl34',
#   'Dnajc24',
#   'Timm50',
#   'Ddx47',
#   'Tgoln1',
#   'Ankrd46',
#   'Gm6548',
#   'Cd44',
#   'Ifi203',
#   'Zfp560',
#   'Armc8',
#   'Dr1',
#   'Mmadhc',
#   'Dda1',
#   'Trp53i11',
#   'Baz1a',
#   'Sdf2l1',
#   'Plscr1',
#   'Cenpq',
#   'Rfk',
#   'Pydc4',
#   'Fgl2',
#   'Uckl1',
#   'Ms4a4c',
#   'Cpne1',
#   'Clk4',
#   'Arf6',
#   'Hsd11b1',
#   'Rbm27',
#   '4933407H18Rik',
#   'Rfwd2',
#   'Nqo2',
#   'Cct2',
#   'Med31',
#   'Casp8',
#   'Mta2',
#   '1810026B05Rik',
#   'Psmd5',
#   'Cdk5',
#   'Dhps',
#   'Zfp292',
#   'Acot8',
#   'Mdfic',
#   'Dnajc4',
#   'Usp15',
#   'Aph1a',
#   'Ppa1',
#   '1810030N24Rik',
#   'Flt3l',
#   'Ssr3',
#   'Pnpt1',
#   'Mbtd1',
#   'Nucks1',
#   'Asna1',
#   'Plrg1',
#   'Fam133b',
#   'Fam100a',
#   'Gtf2f2',
#   'Cd2bp2',
#   'Vps11',
#   '3110040N11Rik',
#   'Vps25',
#   'Gng2',
#   'R3hdm1',
#   'Rexo4',
#   'Pkn2',
#   'Chd2',
#   'Ptpn7',
#   'Pafah1b3',
#   'Gpr171',
#   'Zfp68',
#   'Ppdpf',
#   'Spcs3',
#   'Vps54',
#   'Ube3a',
#   'Vmp1',
#   'Tet3',
#   'Csnk1g3',
#   '2010109K11Rik',
#   'Stard7',
#   'Trim27',
#   'Pds5b',
#   'Smndc1',
#   'Nap1l1',
#   'Ccdc85b',
#   'Tnip1',
#   'Crbn',
#   'Mad2l2',
#   'Psmd2',
#   'Coro2a',
#   'Fam176b',
#   'Sh2d1a',
#   'Ccz1',
#   'Plekho2',
#   'D930015E06Rik',
#   'Sfxn1',
#   'Gusb',
#   'Fam54b',
#   'Mll1',
#   'Gtf2a1',
#   'Apoe',
#   'Dpysl2',
#   'Abt1',
#   'Hint2',
#   'Sltm',
#   'Smcr7l',
#   'Tesc',
#   'Mrps5',
#   'Sec63',
#   'Setx',
#   '2310033P09Rik',
#   'Zmat5',
#   'Ubn1',
#   'Mrps17',
#   'Hk1',
#   'Ppp1r15b',
#   'Diablo',
#   'Ptpre',
#   'Def6',
#   'Noc4l',
#   'Gmnn',
#   'Ndfip2',
#   'Tcof1',
#   'Vps26b',
#   'Tyms',
#   'Oxa1l',
#   'Napg',
#   'Trpm7',
#   'Ddt',
#   'Plekhf1',
#   'Dnajb9',
#   'Map2k2',
#   'Itfg1',
#   'Sepp1',
#   'Fam60a',
#   'Rnf5',
#   'Kbtbd2',
#   'D2Wsu81e',
#   'Epb4.1',
#   'Setd1a',
#   'Wdr76',
#   'Srrm1',
#   'Irak2',
#   'Ash2l',
#   '1500012F01Rik',
#   'Rps6kb1',
#   'Unc50',
#   'Mthfs',
#   'Gm1821',
#   'Cenpb',
#   'Pxmp3',
#   'Add3',
#   'Xpa',
#   'Mrpl48',
#   'Atl3',
#   'Ergic1',
#   'Chmp1a',
#   '1110059G10Rik',
#   'Rnpepl1',
#   'Gpx1',
#   'Taf1d',
#   'Raver1',
#   'Slc25a1',
#   'Fbxo8',
#   'Wdr74',
#   'Ddx10',
#   'Tbx21',
#   'Tmbim4',
#   'Sigmar1',
#   'Serpinb6b',
#   '2810453I06Rik',
#   'Fbxl14',
#   'Slc30a5',
#   'Ezh2',
#   'Ccr2',
#   'Ccdc88b',
#   'Ssb',
#   'Ppm1h',
#   'Hexim1',
#   'Xlr4c',
#   'Mll2',
#   'Rasa1',
#   'Adar',
#   'Nasp',
#   'Setd6',
#   'Aplp2',
#   'Rras2',
#   'Cst7',
#   'Wapal',
#   'Pea15a',
#   'Mfap1a',
#   'Ubqln1',
#   'Tmem120a',
#   'Rcan1',
#   'Phf8',
#   'Dpp3',
#   'Uhrf2',
#   'Wdr77',
#   '1700017B05Rik',
#   'Dnajc13',
#   'Rif1',
#   'Spsb3',
#   'Rab3gap1',
#   'Rcc2',
#   'Arhgef2',
#   'Nol11',
#   'Cdipt',
#   'Tnfaip8l2',
#   'Prpf4b',
#   'Rad9',
#   'Kti12',
#   'Vps4a',
#   'March2',
#   'Nsd1',
#   'Ppt2',
#   'Prmt5',
#   'Bckdha',
#   'Plek',
#   'H2-Q8',
#   'Ythdf3',
#   'Rnf44',
#   'Rae1',
#   'Pabpc4',
#   'Ube2r2',
#   'Lrch4',
#   'D17Wsu104e',
#   'Med7',
#   'Gm6251',
#   'Rbm5',
#   'Lpin1',
#   'Golga5',
#   'Gm9781',
#   'Puf60',
#   'Otud5',
#   'Rab1b',
#   'Atp2a3',
#   'Nfkbiz',
#   'Itpr1',
#   'H1f0',
#   'Lysmd2',
#   'Acp1',
#   'Vps13a',
#   'Hagh',
#   'Smad2',
#   'Aim2',
#   'Evl',
#   'Ddx41',
#   'Ugdh',
#   'Xrn2',
#   'Cdt1',
#   'Casp1',
#   'Ormdl1',
#   'Cbx1',
#   'Usp8',
#   'Rab21',
#   'Npepl1',
#   'Nup205',
#   'Nol8',
#   'Rock2',
#   'Zmiz1',
#   'Il3ra',
#   'Eif2ak1',
#   'Tet2',
#   'Srm',
#   '4921524J17Rik',
#   'Stat3',
#   'Nfyb',
#   'Nsmce1',
#   'Ccnd3',
#   'Rbbp7',
#   'Eid1',
#   'Plekha1',
#   'Bmyc',
#   'Lsm12',
#   'Yy1',
#   'Prkcq',
#   'Dguok',
#   '5930416I19Rik',
#   'Atad1',
#   'Paxip1',
#   'Rc3h1',
#   'Anapc10',
#   'Dera',
#   'Psme4',
#   'P4ha1',
#   'Kif2a',
#   '5730455O13Rik',
#   'Aim1',
#   'Ube2l6',
#   'Kctd12',
#   'Myef2',
#   'Plekhb2',
#   'Ubxn2a',
#   'Tmem106c',
#   'Grap2',
#   'Syne1',
#   'C330006A16Rik',
#   'B4galnt1',
#   'Lrrk1',
#   'Camk1d',
#   'Satb1',
#   'Copb1',
#   '1110002B05Rik',
#   'Polr3f',
#   'Ssbp3',
#   'Cno',
#   'Gm5617',
#   'Pex14',
#   'Mcm3',
#   'Rpl34',
#   'Dpf2',
#   'Ftsjd2',
#   'Samd10',
#   'Brd3',
#   'Pdk1',
#   'Sypl',
#   ...],
#  'plasmacytoid_dendritic_cell': None,
#  'b_cell': ['B2m',
#   'H3f3b',
#   'Atp5h',
#   'H2-K1',
#   'Rplp2',
#   'Ndufa13',
#   'Cox6c',
#   'Fth1',
#   'Myl12a',
#   'Cox6b1',
#   'Rps17',
#   'Rpl23',
#   'Ptma',
#   'Rps15',
#   'Gnb2l1',
#   'Eif3k',
#   'Arf1',
#   'Dad1',
#   'Fau',
#   'Tomm6',
#   'Rps24',
#   'Hmgb1',
#   'Ube2d3',
#   'Atp5j2',
#   'Rpl22',
#   'H2-D1',
#   'Rpl28',
#   'Pdia6',
#   'Slc25a3',
#   'Rpl38',
#   'Selk',
#   'Atp5f1',
#   'Tceb2',
#   'Myl6',
#   'Cox5b',
#   '2410006H16Rik',
#   'Bsg',
#   'Snrpg',
#   'Rpl10',
#   'Ndufa4',
#   'Rpl7a',
#   'Gnas',
#   'Cox8a',
#   'Mdh2',
#   'Atp5d',
#   'H2-Ab1',
#   'Arpc5',
#   'Eef1b2',
#   'Rpl5',
#   'Srsf2',
#   'Rpl27',
#   'Rps25',
#   'Rps29',
#   'Cox5a',
#   'Rpl39',
#   'Rpl27a',
#   'Tomm20',
#   'Cox7c',
#   'Calm1',
#   'Rps13',
#   'Rps4x',
#   'Sumo2',
#   'Rpl7',
#   'Serp1',
#   'Jund',
#   'Edf1',
#   'Rpl11',
#   'Ndufb10',
#   'Mef2c',
#   'Rpl19',
#   'Rps2',
#   'Uqcrh',
#   'Rps15a',
#   'Rps27a',
#   'Rps23',
#   'Rpl36',
#   'Pkig',
#   '2410015M20Rik',
#   'Gas5',
#   'Rpsa',
#   'Rpl29',
#   'Naca',
#   'Rpl35a',
#   'Eef1a1',
#   'Arpc2',
#   'Polr2f',
#   'H2-Eb1',
#   'Cox7a2',
#   'Ccdc56',
#   'Usmg5',
#   'Rpl36al',
#   'Tmed2',
#   'Srgn',
#   'Supt4h1',
#   'Nol7',
#   'Arpp19',
#   'Rpl23a',
#   'Rpl41',
#   'Rps16',
#   'Rps8',
#   'Cdc42',
#   'Taldo1',
#   'Gpx4',
#   'Srp14',
#   'Jtb',
#   'Rpl21',
#   'Rpl13a',
#   'Ebp',
#   'Atp5e',
#   'Rpl8',
#   'Uqcrfs1',
#   'Ndufb8',
#   'Ociad1',
#   'Uba52',
#   'Nme1',
#   'Rpl24',
#   'Eif1',
#   'Rpl17',
#   'Rpl18a',
#   'Rpl37a',
#   'Ewsr1',
#   'Ier5',
#   'Tmsb4x',
#   'Uqcrb',
#   'Eif3f',
#   'Pomp',
#   'Rab2a',
#   'Rps3',
#   'Rpl35',
#   'Raly',
#   'Zfand6',
#   'Tmem134',
#   'Set',
#   'Rplp0',
#   'Eef2',
#   'Med28',
#   'Llph',
#   'Rps9',
#   'Rpl36a',
#   'Snx3',
#   'Phf5a',
#   'Gdi2',
#   'Capg',
#   'Ptpn18',
#   'Ftl1',
#   'Atp6v1g1',
#   'Uqcrq',
#   'Lsm4',
#   'Rpl13',
#   'Rpl14',
#   'Rpl9',
#   'Ppia',
#   'H2afy',
#   'Cacybp',
#   'Rps7',
#   'Rpl6',
#   'Eif3i',
# ...
#   'Atp2a3',
#   'Gnai2',
#   'Txndc17',
#   'Mif',
#   'Klf13',
#   'Brp44l',
#   'Srsf5',
#   'Seh1l',
#   'Gm561',
#   'Trappc6a',
#   'Fbxo18',
#   'Prkcsh',
#   'Banf1',
#   'Mlf2',
#   'Gm15421',
#   'Evl',
#   'Ugcg',
#   'Pfdn2',
#   'Otud4',
#   'Trim8',
#   '2410004N09Rik',
#   'Mrpl43',
#   'Sepp1',
#   'Cops7a',
#   'Mafg',
#   'Timm13',
#   'Hdac2',
#   'Ccnl1',
#   'Anxa6',
#   'Apoa1bp',
#   'Sfpi1',
#   'Whsc1l1',
#   'March5',
#   'Dnaja1',
#   'Atf1',
#   'Faim',
#   '2310011J03Rik',
#   'E2f4',
#   'Ccm2',
#   'Apbb1ip',
#   'Vrk1',
#   'Gpx1',
#   'Fam165b',
#   'Dap',
#   'Rpgrip1',
#   'Ctdsp1',
#   'Sept1',
#   '1300018J18Rik',
#   'Psmd9',
#   'Vps72',
#   'Gtf2a1',
#   'Sdhc',
#   'Ei24',
#   'Myg1',
#   'Polr2c',
#   'Slc25a11',
#   'Arpc1a',
#   'Gnb1',
#   'Ndfip1',
#   'Nat9',
#   'Nhp2',
#   'Pcif1',
#   'Snx20',
#   '2310004N24Rik',
#   'Csnk1d',
#   'Sh3glb2',
#   'Ier2',
#   'Suds3',
#   'Cat',
#   'Maf1',
#   'Grcc10',
#   'Igtp',
#   'Usf2',
#   'Rab28',
#   'Pacsin2',
#   'Rab9',
#   'Trip4',
#   'Prr5',
#   'Rpp30',
#   'BC013529',
#   'Itpa',
#   'Aldh9a1',
#   'Acd',
#   'Man1a2',
#   'Atrx',
#   'Gtl3',
#   'Suclg2',
#   'Pdcd7',
#   'Znhit1',
#   'Kdm6b',
#   'Utp3',
#   'Ptpn11',
#   'Mmadhc',
#   'Clptm1l',
#   'Pold4',
#   'Tgif1',
#   'Crlf3',
#   'Trappc2l',
#   'Rgs19',
#   'Dtd1',
#   'Uimc1',
#   'Hnrnpd',
#   'Ccdc117',
#   'Mrps12',
#   'Psmd14',
#   'Hmgn1',
#   'Mrpl12',
#   'Bola3',
#   'Golph3',
#   'Gins4',
#   'Ncf4',
#   'Klhdc3',
#   'Cdc16',
#   'Mta3',
#   'Fkbp1a',
#   'Upf3b',
#   'Nfkbid',
#   'Adam10',
#   '1300002E11Rik',
#   'Sik1',
#   'Adrbk1',
#   'Rce1',
#   'Nubp2',
#   '2310047M10Rik',
#   'Sf3b5',
#   'Fcgrt',
#   '4833439L19Rik',
#   'Asnsd1',
#   'Grina',
#   'Hsd17b10',
#   'Ppp1r18',
#   'Dazap2',
#   'Taok3',
#   'Mtmr2',
#   'Sbds',
#   'Hcst',
#   'Ppp1r37',
#   'Rab8b',
#   'Gpsm3',
#   'Tpd52',
#   'Slc35c2',
#   'Sipa1',
#   'Fbxo22',
#   'Suz12',
#   '2610002J02Rik',
#   'Tpm1',
#   'Magoh',
#   'Smarcb1',
#   'Zbtb4',
#   'Mri1',
#   'Zfp36l2',
#   '0610030E20Rik',
#   'Wdr18',
#   'Cbx4',
#   'Thoc2',
#   'Scp2',
#   'Acadvl',
#   'Mycbp2',
#   'Ube2z',
#   'Nufip2',
#   'Rbms1',
#   'Brms1',
#   'Prelid1',
#   'Elof1',
#   'H2-DMb1',
#   'Utp18',
#   'Gart',
#   'Eif2s1',
#   'Limd2',
#   'Ccdc12',
#   'Ndufv3',
#   'Grsf1',
#   'Cul4b',
#   'Mrpl50',
#   'Wsb1',
#   'Erh',
#   'Cep57',
#   'Tarbp2',
#   'Hint3',
#   'Lgals8',
#   'Map2k7',
#   'Ndufa8',
#   'Ormdl3',
#   '1810046J19Rik',
#   'Obfc2a',
#   'Rps15a-ps4',
#   'Fam195b',
#   'Rock1',
#   'Smek2',
#   'S100a10',
#   'Pfdn1',
#   'Fos',
#   'Gtpbp4',
#   'Bet1l',
#   'Prcp',
#   'Sdc4',
#   'Fam89b',
#   'Cltb',
#   'Krr1',
#   'Cltc',
#   'Pgls',
#   'H2-Ob',
#   'Psmb5',
#   'Lactb',
#   '2300009A05Rik',
#   'Cd2',
#   'Azi2',
#   'Trim25',
#   'Hat1',
#   '0610010K14Rik',
#   'B230219D22Rik',
#   'Mrpl2',
#   'Otub1',
#   'Prkcb',
#   'Gpbp1',
#   'Pak2',
#   'Gm2a',
#   'Mocs2',
#   'Gpatch8',
#   'Ctnnb1',
#   'Tmem41b',
#   'D14Ertd449e',
#   'Inpp5d',
#   'Spint2',
#   'Kdm4c',
#   'Pdzd8',
#   'Tbca',
#   'Ruvbl2',
#   'Med21',
#   '4933433P14Rik',
#   'Ntan1',
#   'Eps15',
#   'Vasp',
#   'Dpp3',
#   'Cebpd',
#   'Ascc1',
#   'Derl2',
#   'Gyg',
#   'Asah1',
#   'Hck',
#   'Serinc1',
#   'Naa40',
#   'Acp1',
#   'Lrmp',
#   'Nr2f6',
#   'Ubr4',
#   'Ccdc109a',
#   'Cnot1',
#   'Tmem93',
#   'Churc1',
#   'Rbpj',
#   'Slc35a4',
#   'Letm1',
#   'Adss',
#   'Rarg',
#   '1810020D17Rik',
#   'Rnmt',
#   'Phb2',
#   'B4galt1',
#   'Ube2a',
#   'Sirpa',
#   'Uxt',
#   'Prdx1',
#   'Cops4',
#   'Cish',
#   'D10Wsu52e',
#   'Letmd1',
#   'Dok3',
#   'Clptm1',
#   'Ctsh',
#   'Mapk1',
#   'Rab3d',
#   'Dync1h1',
#   'Bptf',
#   'Csnk2b',
#   'Stard10',
#   '2010012O05Rik',
#   'Thyn1',
#   'D19Bwg1357e',
#   'Gadd45g',
#   'Tspan14',
#   'Ciz1',
#   'Glud1',
#   'Mapk1ip1l',
#   'Thoc3',
#   'Cul5',
#   'Tuba1a',
#   'Pdhb',
#   'Dbf4',
#   'Aup1',
#   'Rela',
#   'C3',
#   'Cnp',
#   'St8sia4',
#   'Fndc3b',
#   'Ifi47',
#   'BC003266',
#   'Nab1',
#   'Akr7a5',
#   'Mob2',
#   'Rassf3',
#   'BC016423',
#   'Copz2',
#   'H2afv',
#   'Srm',
#   'Srek1ip1',
#   'Qk',
#   'Ogdh',
#   'Rbm43',
#   'Gps2',
#   'Npepl1',
#   'Apoo',
#   'Fam100a',
#   'Zfp148',
#   'Sfr1',
#   'Il2rg',
#   'Itgb7',
#   'Cabin1',
#   'Tbpl1',
#   'Arhgef1',
#   'Arrb1',
#   'Afg3l1',
#   'Marcksl1',
#   'Aco2',
#   'Th1l',
#   'Aldh3b1',
#   'Ehd1',
#   'Cog2',
#   'Leng8',
#   'Arl4a',
#   'Fbxo11',
#   'Trip12',
#   'Samhd1',
#   'Ly6d',
#   'Ndufa10',
#   'Abcf3',
#   'Mrpl28',
#   'Flna',
#   'Phc2',
#   'Mrps34',
#   'Lats2',
#   'Aftph',
#   'Synj2bp',
#   'Bfsp2',
#   'Kdm2b',
#   'Cyb5b',
#   'Fam108b',
#   'Med25',
#   'Rufy1',
#   '1810027O10Rik',
#   'Ppil2',
#   '1110005A03Rik',
#   'Nudt3',
#   '2900010M23Rik',
#   'H1f0',
#   'Ss18',
#   'Gtf3a',
#   'Triap1',
#   'Fnta',
#   'Wtap',
#   'Dcps',
#   'Ralb',
#   'Ppid',
#   'Tiparp',
#   'App',
#   'Nbr1',
#   'D930014E17Rik',
#   'Lgals3bp',
#   'Mrps18c',
#   'Loh12cr1',
#   'Mrps15',
#   'Tmem126b',
#   'Irf1',
#   ...],
#  'myeloid_leukocyte': ['Rplp2',
#   'Rps21',
#   'Rpl28',
#   'Rps27',
#   'H3f3a',
#   'Rps12',
#   'Rps28',
#   'Ubl5',
#   'Psap',
#   'Rps20',
#   'Cyba',
#   'Gapdh',
#   'Actr2',
#   'Rpl31',
#   'Sep15',
#   'Fth1',
#   'Cd300a',
#   'Apoe',
#   'Calm1',
#   'Atp5f1',
#   'Rab32',
#   'Gdi2',
#   'Hnrnpf',
#   'Crip1',
#   'Tpt1',
#   'Stx7',
#   'H2-K1',
#   'Wdr1',
#   'Rap1b',
#   'Khdrbs1',
#   'Pdia6',
#   'Psma2',
#   'Cd53',
#   'Rgs2',
#   'Rps10',
#   'Gabarap',
#   'Tgfb1',
#   'Ndufb2',
#   'Vim',
#   'Ptp4a2',
#   'Fcer1g',
#   'Tmem50a',
#   'Stra13',
#   'Ssb',
#   'Sdcbp',
#   '2900064A13Rik',
#   'Ifngr1',
#   'Bnip3l',
#   'H2-DMb1',
#   'Ndufa3',
#   'Ube2f',
#   'Aes',
#   'Hfe',
#   'Clec4a1',
#   'Frg1',
#   'Cybb',
#   'Gm2a',
#   'Tcp1',
#   'Psmb10',
#   'Psenen',
#   'Cct2',
#   'Atpif1',
#   'Tm6sf1',
#   'Rnasek',
#   'Gusb',
#   'Pdia3',
#   'Polr2j',
#   'Anxa5',
#   'Sec11c',
#   'Psmb3',
#   'Fos',
#   'Irf5',
#   'Dynlrb1',
#   'Arf6',
#   'Sepw1',
#   'Rpn2',
#   'Naaa',
#   'Psmd8',
#   'Ier3ip1',
#   'Anapc13',
#   'Naa50',
#   'Fcgrt',
#   'Pdap1',
#   'Dnajb6',
#   'Ier5',
#   'Top1',
#   'Pnp',
#   'Mapkapk2',
#   '1500012F01Rik',
#   'Serp1',
#   'Tmem123',
#   'Rab11b',
#   'Arl6ip1',
#   'Psma4',
#   'Rab5c',
#   'Tbc1d8',
#   'Rnase6',
#   'Lcp2',
#   '2310044H10Rik',
#   'Kras',
#   'Emp3',
#   'Snx20',
#   'Mtap7d1',
#   'Pabpc1',
#   'Rab43',
#   'Eif5',
#   'Itm2c',
#   'Ppp1cc',
#   'Arl6ip4',
#   'Usf2',
#   'Ndufa11',
#   'Gas5',
#   'St8sia4',
#   'Zfp706',
#   'Gnb1',
#   'Rab4b',
#   'Ctdnep1',
#   'Polr2m',
#   'Mrpl12',
#   'Btg2',
#   'Gsr',
#   'Map2k2',
#   'Copz1',
#   'Mbnl1',
#   'Ifi30',
#   'Cdc34',
#   'Psmg4',
#   'Abi3',
#   'Pgk1',
#   'Gmfg',
#   'Ncf2',
#   'Gm16517',
#   'Jak1',
#   'Psmc3',
#   'Gltp',
#   'Zeb2',
#   'AI607873',
#   'Fermt3',
#   'Dpm3',
#   'Ppp2ca',
#   'H2-Oa',
#   'Trpc4ap',
#   'Coro1c',
#   'Osbpl9',
#   'St3gal4',
#   'Eif3d',
#   'Cbfb',
#   'Lilrb3',
#   'Mgst1',
#   'Rbms1',
#   'Rhoa',
#   'Kcmf1',
#   'Slc25a4',
#   '2900053A13Rik',
#   'Tfg',
#   'Idh3b',
#   'Fbl',
#   'Ndufab1',
#   'Ikzf1',
#   'Asnsd1',
#   'Mndal',
#   'Ccni',
#   'Pilrb1',
#   'Sema4a',
#   'Nans',
#   'D17Wsu104e',
#   'Tmem14c',
#   'Mrpl18',
#   'Hsd17b12',
#   'Sf3b1',
#   'Acer3',
#   'Rpn1',
#   'B4galnt1',
#   'Tmem50b',
#   'Crlf2',
#   'Orai1',
#   'Rn45s',
#   'Slamf8',
#   'Rab24',
#   'Lrp10',
#   'Cox5a',
#   'Zyx',
#   'Trim28',
#   'Stard3nl',
#   'Tnfrsf1a',
#   'Sdf2l1',
#   'Stk24',
#   'Snap23',
#   'Mrp63',
#   'Pxmp3',
#   'Eif1a',
#   'Cnn2',
#   'Ing4',
#   'Brp44l',
#   'Eif4ebp1',
#   'Hsp90aa1',
#   '3110003A17Rik',
#   'Myo1g',
#   'Abhd16a',
#   'Sf3b5',
#   'H2-DMa',
#   'Hspa5',
#   'Cat',
#   'Fam105a',
#   'Dnajb11',
#   'Pa2g4',
#   'Commd8',
#   'Trim8',
#   'Sec11a',
#   'Atp6v1e1',
#   'Ptpn6',
#   'Tnfaip8l2',
#   'Myo9b',
#   'Ndufb9',
#   'Ccndbp1',
#   'Ap1m1',
#   'Tnpo3',
#   'Klf10',
#   'Elovl1',
#   'Ccdc56',
#   'Chmp2a',
#   'Ssr1',
#   'Clec12a',
#   'Ubap2l',
#   'Ifitm2',
#   'Rnpep',
#   'Plbd1',
#   'Pstpip1',
#   'Slc24a6',
#   'Banf1',
#   'Apobr',
#   'Arl4c',
#   'G3bp2',
#   'Ubn1',
#   'Pgs1',
#   'C1qc',
#   'Ltbr',
#   'Hadhb',
#   'Nfu1',
#   'Oaz1',
#   'Uqcrc2',
#   'Eny2',
#   'Pfdn1',
#   'Dnaja1',
#   'Alkbh5',
#   'Ufsp2',
#   'Lst1',
#   'Wasf2',
#   'Sugt1',
#   'Sgta',
#   'Slc11a1',
#   'Psmb7',
#   'B9d2',
#   'Blvrb',
#   'Acsl5',
#   'Ubc',
#   'Myadm',
#   'Apoc1',
#   'Ctage5',
#   'Vrk3',
#   'Psmd1',
#   '4833439L19Rik',
#   'Mfsd1',
#   'Acbd6',
#   'Atf1',
#   'Rnf19b',
#   'Emg1',
#   'Klf6',
#   'Ube2a',
#   'Pdha1',
#   'App',
#   'Rnf166',
#   'Hcfc1r1',
#   'Atp5k',
#   'Ewsr1',
#   'Utp3',
#   'Hdlbp',
#   'Tsc22d3',
#   'Orai3',
#   'Msn',
#   'A430084P05Rik',
#   'Mapk14',
#   'Cd9',
#   'Dusp1',
#   '2810407C02Rik',
#   'Paics',
#   'Plp2',
#   'Ccnd3',
#   'Igsf6',
#   'Hspa14',
#   'Ywhah',
#   'Taf12',
#   'Csnk1g2',
#   'D4Ertd22e',
#   'Tprgl',
#   'Hif1a',
#   'Mcl1',
#   'Aco2',
#   'Lamp2',
#   'Emr4',
#   'Mycbp2',
#   'Rrbp1',
#   'Cyb5r4',
#   'Adrbk2',
#   'Rrp1',
#   'Inpp5d',
#   'Eif4e2',
#   'Relb',
#   'Hnrnpm',
#   'Zfp36',
#   'Acaa1a',
#   'Ppp3ca',
#   'Phf5a',
#   'Tmem30a',
#   'Hnrnph2',
#   'Rdbp',
#   'Irf8',
#   'Edem2',
#   'Lsm7',
#   'Gpr108',
#   'B230219D22Rik',
#   'Triobp',
#   'Mrps16',
#   'Zc3h15',
#   'Vrk1',
#   'Pycrl',
#   'Gng10',
#   'Yif1b',
#   'Glrx5',
#   'Rnf4',
#   'Slc29a1',
#   'Sept9',
#   'Serpinb6b',
#   'Arl3',
#   'Dpy30',
#   'Pin4',
#   'Rps15a-ps6',
#   'Prpf19',
#   'Atxn7l3b',
#   'Rnf34',
#   'Ddx39',
#   'Pak1',
#   'Arhgap18',
#   'Pdlim5',
#   'Ece1',
#   'Bccip',
#   'Chmp5',
#   'Maea',
#   'Tssc1',
#   'Dpf2',
#   'Tomm5',
#   'Stk38',
#   'Sepp1',
#   'Ehbp1l1',
#   'Fnbp1',
#   'Txn2',
#   'Acadl',
#   'AI462493',
#   'Rock1',
#   'Pyhin1',
#   'Pttg1',
#   'Fam165b',
#   'Ube3a',
#   'Dock8',
#   'Acp5',
#   'Ankrd12',
#   'Txn1',
#   'Ube2w',
#   'Rfxap',
#   'Naa15',
#   'Btg1',
#   'Metrnl',
#   'Ddx6',
#   'Guca1a',
#   'S100a4',
#   'Coro7',
#   'Vbp1',
#   'Letm1',
#   'Hist2h2aa1',
#   'Lbr',
#   'Rps6ka1',
#   'Junb',
#   'Acot9',
#   'Irf2',
#   'Tnfrsf1b',
#   'Ppt1',
#   'Rasa4',
#   'Psmc1',
#   'Slc50a1',
#   'Coro2a',
#   'Pea15a',
#   'Txndc15',
#   'Mrpl48',
#   'Vamp3',
#   'Mrpl32',
#   'Dbndd2',
#   'Cdk19',
#   'Cdipt',
#   'Sertad2',
#   'Kpna4',
#   'Nap1l4',
#   'Pdcd5',
#   'Slc25a39',
#   'Rab8a',
#   'Pilrb2',
#   'Scamp2',
#   'Cpsf6',
#   'Pes1',
#   'Epn1',
#   'Yipf3',
#   'Ilkap',
#   'Lrrfip1',
#   'Yipf4',
#   'Asap1',
#   '2010003O02Rik',
#   'Rfc1',
#   'Ube2v2',
#   'Hsd17b11',
#   'Fubp1',
#   '2310039H08Rik',
#   'Rnaset2b',
#   'Fam117b',
#   'Jmjd6',
#   'Tm9sf1',
#   'Srgn',
#   'Tmed2',
#   'Tmem165',
#   '2410004N09Rik',
#   'Iqgap1',
#   'Dctpp1',
#   'Txnl1',
#   'Xdh',
#   'Gmip',
#   'Smarcb1',
#   'Commd4',
#   'Mrpl41',
#   'Lbh',
#   'Pmpca',
#   'Itgb1',
#   'Rbm6',
#   'Klf13',
#   'Stx16',
#   'Tpr',
#   'Tsc22d4',
#   'Sept6',
#   'Prdx5',
#   'Pdcd6',
#   'Tmbim4',
#   'Hhex',
#   'Adam17',
#   'Bad',
#   'Fxr2',
#   'Thoc3',
#   'Cited2',
#   'Gm6654',
#   'Akt1',
#   'Amz1',
#   'Picalm',
#   'Gipc1',
#   'BC035044',
#   'Arfrp1',
#   'Naip2',
#   'B230208H17Rik',
#   'Ms4a6b',
#   'Tmem214',
#   'Nsun2',
#   'Pofut2',
#   'Dhx40',
#   'Taz',
#   'Tagap',
#   'Ccr2',
#   'Taf13',
#   'Ccar1',
#   'Cisd1',
#   'U2af1',
#   'Adam15',
#   'Arid1a',
#   'Ppp1r9b',
#   'Dcaf12',
#   'Peli1',
#   'Nipbl',
#   'Rasgrp2',
#   'Cd81',
#   'Insig2',
#   'Notch2',
#   'Ctbp1',
#   'Cpne2',
#   'Psmd11',
#   'Glrx2',
#   'Rab35',
#   'Slc46a3',
#   'Rpia',
#   'Gm5150',
#   'Gba',
#   'Tuba1c',
#   'Hdac2',
#   'Atp6v1b2',
#   'Prkch',
#   'Rbm38',
#   'Ifi204',
#   'Capn2',
#   'Serhl',
#   'Cnot8',
#   'Nufip2',
#   'Fam168b',
#   '2610001J05Rik',
#   'Pik3cd',
#   'Clns1a',
#   'Slc25a17',
#   'Gng12',
#   'Fam63b',
#   'Trmt1',
#   'BC003266',
#   'Slc35a4',
#   'Hk3',
#   'Mir703',
#   'Comt',
#   'Cdc40',
#   'Mosc2',
#   'Pank2',
#   'Bach1',
#   'Btf3l4',
#   'Tradd',
#   'Dars',
#   'Zfand3',
#   'Ptpra',
#   'Crcp',
#   'Ube2b',
#   'Lat2',
#   'AI314976',
#   'Trf',
#   'Cse1l',
#   'Kpnb1',
#   'Dnajc15',
#   'Gak',
#   'Rassf3',
#   '6330407A03Rik',
#   'Plekhf2',
#   'Pilra',
#   'Ralbp1',
#   'Pon2',
#   'Ckb',
#   'Otub1',
#   'Immp1l',
#   'BC031181',
#   'Lyrm2',
#   'Fbxl5',
#   'Meaf6',
#   'Klf2',
#   'Hsd3b7',
#   'Pno1',
#   'Adrm1',
#   'Acvrl1',
#   'Ino80e',
#   'Dnaja2',
#   'Ndnl2',
#   'Srsf6',
#   'Anxa6',
#   'Nampt',
#   'Ccdc75',
#   'Pgm1',
#   'H2-Q4',
#   'Mob3a',
#   'Tbc1d22a',
#   'Atic',
#   'Apobec1',
#   'Crtc2',
#   'Tcf7l2',
#   'Timm50',
#   'Ncf1',
#   'Psma6',
#   'Dld',
#   'Ly6a',
#   'Xab2',
#   'Stk4',
#   'Scpep1',
#   'Smad1',
#   'Lsmd1',
#   'Mapk7',
#   'Usp3',
#   'Gpaa1',
#   'Ptprs',
#   'Med13',
#   'Lass2',
#   'Rgs19',
#   'Igf1',
#   'Trip12',
#   '6430548M08Rik',
#   'Stx6',
#   'Anp32a',
#   'Cdk2ap1',
#   'Stk25',
#   'Fyb',
#   'Chchd5',
#   'Pion',
#   'Itgb7',
#   'Gtf3c2',
#   'Clec4a3',
#   'Dynlt3',
#   'Cdkn2aipnl',
#   'Rgs1',
#   'Fbxw2',
#   'Hmox2',
#   'Tax1bp1',
#   'Map2k1',
#   'Tnip1',
#   'Gpr141',
#   'Sipa1',
#   'Snrnp70',
#   'Pphln1',
#   'BC003331',
#   'Gosr2',
#   'Mllt10',
#   'Dpysl2',
#   'Lsm1',
#   'Nudt16',
#   'Eif1ax',
#   'Ccnk',
#   'Atp6v1a',
#   'Sgk1',
#   'Adap1',
#   'Pfkl',
#   'Treml4',
#   'Cttnbp2nl',
#   'Ict1',
#   'Mterfd1',
#   'Zfp830',
#   'Cybasc3',
#   'Zfp414',
#   'Ddx56',
#   'Fh1',
#   'Ninj1',
#   'BC006779',
#   'Rnf220',
#   'Hmha1',
#   'Esyt1',
#   'Psmc4',
#   'Chchd7',
#   'Ruvbl1',
#   '6330416G13Rik',
#   'Nosip',
#   'Rgs18',
#   'Gps2',
#   '2210013O21Rik',
#   'Slc29a3',
#   'Ms4a4c',
#   'Fbxo8',
#   'Copa',
#   'Neurl3',
#   'Rtp4',
#   'Limd1',
#   'Pigf',
#   'Rad21',
#   'Vwa5a',
#   '1810046J19Rik',
#   'Fndc3a',
#   'Anxa3',
#   'Max',
#   'Ccnd1',
#   'Plekha1',
#   'Lsr',
#   'Gemin7',
#   'Fn1',
#   'Mfap3',
#   'Bub3',
#   'Uchl5',
#   'Atp1b3',
#   'Ifi203',
#   'Phf20',
#   'Gm1821',
#   'Tmem71',
#   '0610007P14Rik',
#   'Hagh',
#   'Ggta1',
#   'Plekhb2',
#   'Cyfip1',
#   'Sp110',
#   'Mlec',
#   'Map3k2',
#   'Dapp1',
#   'Ube2h',
#   'Mtmr3',
#   'Rap2b',
#   'Npm3',
#   'Spns1',
#   'Hdgfrp2',
#   'Nrp',
#   'Zdhhc7',
#   'P2rx4',
#   'Ncoa6',
#   'Unc119',
#   'Prdm1',
#   'Rpe',
#   'Fgd2',
#   'Dpagt1',
#   'Adck4',
#   'BC037034',
#   'Capn1',
#   'Tsnax',
#   'Siglece',
#   'Chchd4',
#   'Hes6',
#   'Sympk',
#   'Adrbk1',
#   'Rps15a-ps4',
#   'Ccdc59',
#   'Dusp11',
#   'Snapin',
#   '2610002J02Rik',
#   'Tmem141',
#   'Fam50a',
#   'Ccm2',
#   'Camk2d',
#   'Cenpv',
#   'Cdk4',
#   'Zmpste24',
#   'Stk16',
#   'Casp2',
#   'H2afx',
#   'Samhd1',
#   'Rasgrp4',
#   'Grina',
#   'Ang',
#   'Usp14',
#   'Ehd1',
#   'Cxcl16',
#   'E2f1',
#   'Twf1',
#   'Tmem11',
#   'Cyp4f16',
#   'Trpv2',
#   'Hist1h2ao',
#   '1810026B05Rik',
#   'Srek1ip1',
#   'Spint2',
#   'Ccdc85b',
#   'Mospd3',
#   'Nxf1',
#   'Tmem173',
#   'E230029C05Rik',
#   'Gmppa',
#   'D10Wsu52e',
#   'D6Wsu163e',
#   'Vcpip1',
#   'St3gal1',
#   'Ttc15',
#   'Chd7',
#   'Whsc1',
#   'Pik3r1',
#   'Nmt1',
#   'Mogs',
#   'Fam49a',
#   'Hpx',
#   'Ccdc101',
#   'Nlrc5',
#   'Hook3',
#   'Itgb5',
#   'Rbm17',
#   'Nkiras2',
#   'Ciita',
#   'Agpat5',
#   'Camkk2',
#   'Polr1a',
#   'Sertad1',
#   'Gbp3',
#   'Pvrl1',
#   'Mrpl37',
#   'Dapk3',
#   'Sh3tc1',
#   '2510002D24Rik',
#   'Sap30l',
#   'Impdh2',
#   'Fnip1',
#   'Cd40',
#   'Stip1',
#   'Cd1d1',
#   'Brcc3',
#   'Rhog',
#   'Aspscr1',
#   'Akna',
#   'BC029722',
#   'Cd8a',
#   'Crlf3',
#   'Zfp259',
#   'Ivns1abp',
#   'Eif2s3x',
#   'Aim2',
#   'Slc25a1',
#   'Efr3a',
#   'St3gal5',
#   'Rassf1',
#   'BC064078',
#   'BC147527',
#   'Slc25a22',
#   'Agpat1',
#   'Folr2',
#   'Agpat4',
#   'Thoc5',
#   'Trim30d',
#   'Cfh',
#   '1810020D17Rik',
#   'Bmyc',
#   'Arsb',
#   'Man2b1',
#   'Rcc2',
#   'Arl5c',
#   'Gatad2b',
#   'Dnajc9',
#   'Elmo2',
#   'Cebpa',
#   'Sqstm1',
#   'Hebp1',
#   'Preb',
#   'Cacybp',
#   'Ppp1r14a',
#   'Cd5l',
#   '9130011J15Rik',
#   'Tbc1d10c',
#   'Rnf145',
#   'Btla',
#   'Oxa1l',
#   'Nipsnap3b',
#   'Slc30a5',
#   'Phyh',
#   'Mx1',
#   'Pfkp',
#   'Sin3b',
#   'Setd5',
#   'Mta2',
#   'Zfp871',
#   'Gdap2',
#   'Tmem131',
#   'Mgat2',
#   'Mapkapk3',
#   'Ccnd2',
#   'Ctdsp2',
#   'Ano6',
#   'Ndst2',
#   'Parp10',
#   'Frmd4b',
#   'Sec62',
#   'A130040M12Rik',
#   'Ehmt2',
#   'Hnrnph3',
#   'Ccnh',
#   'Nat6',
#   'Mxi1',
#   'Kmo',
#   'Ddx54',
#   'Asxl2',
#   'Tmem55b',
#   'Rbmxl1',
#   'Mettl10',
#   'Cnnm4',
#   'Phka2',
#   'Sigmar1',
#   'Rap2a',
#   'Pkn2',
#   'Bclaf1',
#   'Srsf10',
#   'Cebpd',
#   'Sdc3',
#   'Pla2g16',
#   'Srp68',
#   'Tra2a',
#   'Atp13a1',
#   'Mtor',
#   'Swi5',
#   'Minpp1',
#   'Slc20a1',
#   'Nt5m',
#   'Rpf1',
#   'Cpsf3l',
#   'Bcl2a1d',
#   'Nup50',
#   'Ubl7',
#   'Hmox1',
#   'Prorsd1',
#   'D4Wsu53e',
#   'Anks3',
#   'Mrpl45',
#   'Atg12',
#   'Insig1',
#   'Prpsap2',
#   'Wbscr22',
#   'Serf1',
#   'Ppp5c',
#   'Rprd2',
#   'Rbmx2',
#   'Entpd1',
#   'Trafd1',
#   'Appbp2',
#   'Rars2',
#   'Tmem206',
#   'Cln3',
#   'Arfgap2',
#   'Hist1h4i',
#   'Il2rg',
#   'Rgl2',
#   'Nfkbil1',
#   'Osbpl3',
#   'Slc33a1',
#   'Lilrb4',
#   'Vps26a',
#   'Sbf1',
#   'Gm6402',
#   'Eci1',
#   'C130039O16Rik',
#   'Pex7',
#   'Tifab',
#   'Wbp2',
#   'Exoc3',
#   'Rsbn1l',
#   'Gtpbp6',
#   'Sirpb1b',
#   'Zfp385a',
#   'Srsf9',
#   'Vat1',
#   'Ppm1m',
#   'Wdfy4',
#   'Rpgrip1',
#   'Lxn',
#   '1600012H06Rik',
#   'Noa1',
#   'Casp7',
#   'Arid1b',
#   'Pmm2',
#   'Dpp4',
#   'Golga4',
#   'Uba2',
#   'Tacc1',
#   'Plekho1',
#   'Znhit2-ps',
#   'Frrs1',
#   'Vps54',
#   'Zdhhc6',
#   'Serpinb9',
#   'Rpa1',
#   'Rbm4',
#   'Cd93',
#   'Tubgcp2',
#   'Polr2l',
#   'Ube2q2',
#   'Pot1b',
#   'Spsb3',
#   'Bloc1s2',
#   'Dlst',
#   'Stam2',
#   'Chmp6',
#   'Arf4',
#   'Nfkbia',
#   'Cript',
#   'Arl2',
#   'Aagab',
#   'Ric8',
#   'Ext2',
#   'Cdc42se1',
#   'Atg4c',
#   'Orc6',
#   'Raver1',
#   'Mki67ip',
#   'Traf6',
#   'Gaa',
#   'Nt5c2',
#   'Tmem176a',
#   '0610007P22Rik',
#   'Slc12a9',
#   'Mettl21d',
#   'Snrk',
#   'Itga4',
#   '4930526I15Rik',
#   'Cebpb',
#   'Oxsr1',
#   'Golga5',
#   'Tnip2',
#   'Antxr2',
#   'Cul5',
#   'Mx2',
#   'Lair1',
#   'Cab39l',
#   'Tmem85',
#   'Ccdc88b',
#   'Ankfy1',
#   'Dnmt3a',
#   'Agxt2l2',
#   'Timp2',
#   'Cklf',
#   'Rnf123',
#   'Ubtd1',
#   'Maf',
#   'Sla',
#   'Cpsf4',
#   'Lactb',
#   'Tbc1d14',
#   'Trnau1ap',
#   'Atf4',
#   'Mrpl2',
#   'Pan3',
#   'Ankra2',
#   'Rangap1',
#   ...]}

# %%
from matplotlib_venn import venn3
from sklearn.metrics import PrecisionRecallDisplay, RocCurveDisplay, roc_curve, precision_recall_curve
from random import sample

sns.set_palette("Set2")

# get PR curve

def plot_PR_ROC(ctrl_test_meta_df, decoded_0_0, decoded_0_1, de_bulk_genes, curr_cell_type, sn_DE_ref, sn_sc_DE_ref, axs, union_genes_cap):

    # this is for the "projected" expression
    curr_idx = np.where(ctrl_test_meta_df.Y_max == curr_cell_type)[0]
    proj_ctrl = decoded_0_0[curr_idx]
    proj_stim = decoded_0_1[curr_idx]

    # take the median for nomalization
    proj_ctrl = np.median(rankdata(proj_ctrl, axis=1), axis=0)
    proj_stim = np.median(rankdata(proj_stim, axis=1), axis=0)
    proj_log2FC = abs(proj_stim-proj_ctrl)

    # make dataframe of true/false positives
    proj_log2FC_df = pd.DataFrame(proj_log2FC, index=union_genes_cap)
    proj_log2FC_df["orig"] = proj_stim-proj_ctrl

    # make a random one
    proj_log2FC_df["random"] = sample(proj_log2FC_df[0].tolist(), len(proj_log2FC_df[0].tolist()))

    # compare with bulk alone
    proj_log2FC_df["bulk"] = de_bulk_genes.log2FC.loc[union_genes_cap]

    proj_log2FC_df["sn_DE"] = 0
    proj_log2FC_df.sn_DE[np.where(np.isin(union_genes_cap, sn_DE_ref))[0]] = 1

    proj_log2FC_df["sc_sn_DE"] = 0
    proj_log2FC_df.sc_sn_DE[np.where(np.isin(union_genes_cap, sn_sc_DE_ref))[0]] = 1



    # now do the single-nucleus cell type specific DE
    roc_display = RocCurveDisplay.from_predictions(proj_log2FC_df.sn_DE, proj_log2FC_df[0], name="BuDDI", ax=axs[0,0])
    pr_display = PrecisionRecallDisplay.from_predictions(proj_log2FC_df.sn_DE, proj_log2FC_df[0], name="BuDDI", ax=axs[0,1])


    roc_display = RocCurveDisplay.from_predictions(proj_log2FC_df.sn_DE, proj_log2FC_df.random, name="random",ax= axs[0,0])
    pr_display = PrecisionRecallDisplay.from_predictions(proj_log2FC_df.sn_DE, proj_log2FC_df.random, name="random", ax=axs[0,1])

    roc_display = RocCurveDisplay.from_predictions(proj_log2FC_df.sn_DE, proj_log2FC_df.bulk, name="bulk",ax= axs[0,0])
    pr_display = PrecisionRecallDisplay.from_predictions(proj_log2FC_df.sn_DE, proj_log2FC_df.bulk, name="bulk", ax=axs[0,1])


    # now do the single-nucleus cell type specific DE
    roc_display = RocCurveDisplay.from_predictions(proj_log2FC_df.sc_sn_DE, proj_log2FC_df[0], name="BuDDI", ax=axs[1,0])
    pr_display = PrecisionRecallDisplay.from_predictions(proj_log2FC_df.sc_sn_DE, proj_log2FC_df[0], name="BuDDI", ax=axs[1,1])


    roc_display = RocCurveDisplay.from_predictions(proj_log2FC_df.sc_sn_DE, proj_log2FC_df.random, name="random",ax= axs[1,0])
    pr_display = PrecisionRecallDisplay.from_predictions(proj_log2FC_df.sc_sn_DE, proj_log2FC_df.random, name="random", ax=axs[1,1])

    roc_display = RocCurveDisplay.from_predictions(proj_log2FC_df.sc_sn_DE, proj_log2FC_df.bulk, name="bulk",ax= axs[1,0])
    pr_display = PrecisionRecallDisplay.from_predictions(proj_log2FC_df.sc_sn_DE, proj_log2FC_df.bulk, name="bulk", ax=axs[1,1])

    sn_avg_pr_BuDDI = average_precision_score(proj_log2FC_df.sn_DE, proj_log2FC_df[0])
    sn_avg_pr_random = average_precision_score(proj_log2FC_df.sn_DE, proj_log2FC_df.random)
    sn_avg_pr_bulk = average_precision_score(proj_log2FC_df.sn_DE, proj_log2FC_df.bulk)

    sc_sn_avg_pr_BuDDI = average_precision_score(proj_log2FC_df.sc_sn_DE, proj_log2FC_df[0])
    sc_sn_avg_pr_random = average_precision_score(proj_log2FC_df.sc_sn_DE, proj_log2FC_df.random)
    sc_sn_avg_pr_bulk = average_precision_score(proj_log2FC_df.sc_sn_DE, proj_log2FC_df.bulk)

    res_df = pd.DataFrame([sn_avg_pr_BuDDI, sn_avg_pr_random, sn_avg_pr_bulk,
                                  sc_sn_avg_pr_BuDDI, sc_sn_avg_pr_random, sc_sn_avg_pr_bulk])
    res_df.columns = ["scores"]
    res_df["metric"] = ["avg_pr"]*6
    res_df["cell_type"] = [curr_cell_type]*6
    res_df["ref_set"] = ["sn"]*3+["sc_sn"]*3
    res_df["method"] = ["BuDDI", "random", "bulk"]*2

    return axs, proj_log2FC_df, res_df

# %%
min_overlap = 50

# %%
de_genes.keys()
# Out:
# dict_keys(['hepatocyte', 'hepatic_sinusoid', 'kupffer', 'hepatic_stellate', 'NK', 'plasmacytoid_dendritic_cell', 'b_cell', 'myeloid_leukocyte'])

# %%
# get PR curve

curr_cell_type = "hepatocyte"
all_cell_types = ["hepatocyte", "hepatic_sinusoid", "kupffer",
                  "hepatic_stellate", "NK", "b_cell"]
all_DE_ref = [Pub_DE_hsc, Pub_DE_hepatic, Pub_DE_kupffer, 
              Pub_DE_hsc, Pub_DE_immune, Pub_DE_immune]


all_res_df = None
curr_idx = 0
for curr_cell_type in all_cell_types:

    print(curr_cell_type)

    # get our DE genes
    de_genes_curr = de_genes[curr_cell_type]
    if de_genes_curr is not None:
        de_genes_curr = [x.upper() for x in de_genes_curr]


    # get bulk DE genes

    # set the reference genes
    DE_ref = Pub_DE
    ct_DE_ref = all_DE_ref[curr_idx]
    extra_ref = ct_DE_ref
    if de_genes_curr is not None:
        extra_ref = np.union1d(de_genes_curr[:min_overlap], ct_DE_ref)


    fig, axs = plt.subplots(2, 2, figsize=(12, 6))
    axs, proj_log2FC_df, res_df = vp.plot_PR_ROC_liver(res1_meta_df, res1_decoded_0_0, res1_decoded_0_1, 
                                        bulk_sig_df, curr_cell_type, ct_DE_ref, extra_ref, 
                                        axs, union_genes_cap, method_name="BuDDI")

    res_df["run_id"] = 1
    all_res_df = pd.concat([all_res_df, res_df])
    
    fig, axs = plt.subplots(2, 2, figsize=(12, 6))
    axs, proj_log2FC_df, res_df = vp.plot_PR_ROC_liver(res2_meta_df, res2_decoded_0_0, res2_decoded_0_1, 
                                        bulk_sig_df, curr_cell_type, ct_DE_ref, extra_ref, 
                                        axs, union_genes_cap, method_name="BuDDI")

    res_df["run_id"] = 2
    all_res_df = pd.concat([all_res_df, res_df])
    
    fig, axs = plt.subplots(2, 2, figsize=(12, 6))
    axs, proj_log2FC_df, res_df = vp.plot_PR_ROC_liver(res3_meta_df, res3_decoded_0_0, res3_decoded_0_1, 
                                        bulk_sig_df, curr_cell_type, ct_DE_ref, extra_ref, 
                                        axs, union_genes_cap, method_name="BuDDI")

    res_df["run_id"] = 3
    all_res_df = pd.concat([all_res_df, res_df])
    

    curr_idx = curr_idx + 1
# Out:
# hepatocyte
# hepatic_sinusoid
# kupffer
# hepatic_stellate
# NK
# b_cell
# Error in callback <function flush_figures at 0x7ff994500670> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     118         # ignore the tracking, just draw and close all figures
#     119         try:
# --> 120             return show(True)
#     121         except Exception as e:
#     122             # safely show traceback if in IPython, else raise
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      38     try:
#      39         for figure_manager in Gcf.get_all_fig_managers():
# ---> 40             display(
#      41                 figure_manager.canvas.figure,
#      42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     251
#     252     if 'png' in formats:
# --> 253         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     254     if 'retina' in formats or 'png2x' in formats:
#     255         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     135         FigureCanvasBase(fig)
#     136
# --> 137     fig.canvas.print_figure(bytes_io, **kw)
#     138     data = bytes_io.getvalue()
#     139     if fmt == 'svg':
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     506             *metadata*, including the default 'Software' key.
#     507         """
# --> 508         FigureCanvasAgg.draw(self)
#     509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2788
#    2789             self.patch.draw(renderer)
# -> 2790             mimage._draw_list_compositing_images(
#    2791                 renderer, self, artists, self.suppressComposite)
#    2792
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2919             renderer.stop_rasterizing()
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#    2923         renderer.close_group('axes')
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1153         self._update_label_position(renderer)
#    1154
# -> 1155         self.label.draw(renderer)
#    1156
#    1157         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/text.py in draw(self, renderer)
#     677
#     678         with _wrap_text(self) as textobj:
# --> 679             bbox, info, descent = textobj._get_layout(renderer)
#     680             trans = textobj.get_transform()
#     681
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     312             clean_line, ismath = self._preprocess_math(line)
#     313             if clean_line:
# --> 314                 w, h, d = renderer.get_text_width_height_descent(
#     315                     clean_line, self._fontproperties, ismath=ismath)
#     316             else:
#
# ~/miniconda3/envs/sc_bulk_ood/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     238         flags = get_hinting_flag()
#     239         font = self._get_agg_font(prop)
# --> 240         font.set_text(s, 0.0, flags=flags)
#     241         w, h = font.get_width_height()  # width and height of unrotated string
#     242         d = font.get_descent()
#
# KeyboardInterrupt:

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8), dpi=216)
axs, proj_log2FC_df, res_df = vp.plot_PR_ROC_liver(res1_meta_df, res1_decoded_0_0, res1_decoded_0_1, 
                                    bulk_sig_df, "hepatocyte", ct_DE_ref, extra_ref, 
                                    axs, union_genes_cap, method_name="BuDDI")

# %%
# plot
fig, axs = plt.subplots(1, 2, figsize=(20,10))

sns.boxplot(data=all_res_df[all_res_df["ref_set"] == "sn"], 
            x="cell_type", y="scores",
            hue="method", ax= axs[0])
axs[0].set_title("AUPRC comparison with SN results")
axs[0].set(ylabel="AUPRC")
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=45, horizontalalignment='right')


sns.boxplot(data=all_res_df[all_res_df["ref_set"] == "sc_sn"], 
            x="cell_type", y="scores",
            hue="method", ax= axs[1])
axs[1].set_title("AUPRC comparison with SN+SC results")
axs[1].set(ylabel="AUPRC")
axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=45, horizontalalignment='right')


fig.suptitle("AUPRC comparison across methods", fontsize=14)

fig.show()

# %%
all_res_df
# Out:
#       scores  metric   cell_type ref_set  method  run_id
# 0   0.301158  avg_pr  hepatocyte      sn   BuDDI       1
# 1   0.005002  avg_pr  hepatocyte      sn  random       1
# 2   0.175556  avg_pr  hepatocyte      sn    bulk       1
# 3   0.131697  avg_pr  hepatocyte   sc_sn   BuDDI       1
# 4   0.008579  avg_pr  hepatocyte   sc_sn  random       1
# ..       ...     ...         ...     ...     ...     ...
# 1   0.001892  avg_pr      b_cell      sn  random       3
# 2   0.226276  avg_pr      b_cell      sn    bulk       3
# 3   0.124865  avg_pr      b_cell   sc_sn   BuDDI       3
# 4   0.002865  avg_pr      b_cell   sc_sn  random       3
# 5   0.114781  avg_pr      b_cell   sc_sn    bulk       3
#
# [108 rows x 6 columns]

# %% [markdown]
# ### write out results table

# %%
out_res_path = Path(f"{res_data_path}/BuDDI_auprc.csv")  

all_res_df.to_csv(out_res_path)
